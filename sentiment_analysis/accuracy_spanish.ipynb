# %%
import requests
import numpy as np
import pandas as pd
from transformers import pipeline
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# # Load Data

# %%
# Load the CSV file into a DataFrame
df_es = pd.read_csv('https://raw.githubusercontent.com/svisel22/SS23-BIPM-Analytics-Lab---Group-4-repository/main/Preprocessing/data_clean/labeled-data/labeled-es_clean_1-1.csv', sep=';')

# %%
df_es.head()
# Out:
#                                                 data    player language  \
# 0  adeyemi firmo el que es su primer gol en lo qu...  palacios       es
# 1  el club aleman, que siempre se ha caracterizad...  palacios       es
# 2  alberto fernandez  el presidente de la afa, cl...  palacios       es
# 3  alberto fernandez  tambien participaron los ot...  palacios       es
# 4  fue el momento en que desde las tribunas se de...  palacios       es
#
#             publishedAt Label
# 0  2023-01-29T18:25:03Z   NaN
# 1  2023-01-31T20:41:38Z   NaN
# 2  2023-02-09T18:32:38Z   NaN
# 3  2023-02-12T21:13:55Z   NaN
# 4  2023-02-13T01:05:15Z   NaN

# %% [markdown]
# ### Fix NA

# %%
#for DE datasate drop empty lines
df_es = df_es.dropna(subset=['data'])

# %% [markdown]
# # Sentiment analysis full text

# %%
sentiment_classifier1 = pipeline('sentiment-analysis', model='finiteautomata/beto-sentiment-analysis')

# %%
sentiment_classifier2 = pipeline('sentiment-analysis', model='dccuchile/bert-base-spanish-wwm-uncased')
# Out:
# Some weights of the model checkpoint at dccuchile/bert-base-spanish-wwm-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dccuchile/bert-base-spanish-wwm-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
'''
def perform_comparison_sentiment_analysis(df, sentiment_classifier):
    # Create empty lists to store the sentiment scores and labels
    sentiment_scores = []
    sentiment_labels = []

    # Iterate over the 'data' column in the DataFrame
    for text in df['data']:
        # Perform sentiment analysis using the Hugging Face pipeline
        result = sentiment_classifier(text)[0]
        sentiment_score = result['score']
        
        # Convert logits to predicted label (positive/negative)
        predicted_label = 1 if sentiment_score > 0.5 else 0
        sentiment_label = "positiv" if predicted_label == 1 else "negativ"

        # Append the sentiment score and label to the respective lists
        sentiment_scores.append(sentiment_score)
        sentiment_labels.append(sentiment_label)

    # Add the sentiment scores and labels as new columns in the DataFrame
    df['sentiment_score'] = sentiment_scores
    df['sentiment_label'] = sentiment_labels

    return df
'''
#three labels:

def perform_comparison_sentiment_analysis(df, sentiment_classifier):
    # Create empty lists to store the sentiment scores and labels
    sentiment_scores = []
    sentiment_labels = []

    # Iterate over the 'data' column in the DataFrame
    for text in df['data']:
        # Perform sentiment analysis using the Hugging Face pipeline
        result = sentiment_classifier(text)[0]
        sentiment_score = result['score']
        
        # Determine sentiment label based on sentiment score
        if sentiment_score > 0.6:
            sentiment_label = "positive"
        elif sentiment_score < 0.4:
            sentiment_label = "negative"
        else:
            sentiment_label = "neutral"

        # Append the sentiment score and label to the respective lists
        sentiment_scores.append(sentiment_score)
        sentiment_labels.append(sentiment_label)

    # Add the sentiment scores and labels as new columns in the DataFrame
    df['sentiment_score'] = sentiment_scores
    df['sentiment_label'] = sentiment_labels

    return df


# Perform sentiment analysis on the DataFrame
df1 = perform_comparison_sentiment_analysis(df_es, sentiment_classifier1)

# Print the updated DataFrame
df1.head()
# Out:
#                                                 data    player language  \
# 0  adeyemi firmo el que es su primer gol en lo qu...  palacios       es
# 1  el club aleman, que siempre se ha caracterizad...  palacios       es
# 2  alberto fernandez  el presidente de la afa, cl...  palacios       es
# 3  alberto fernandez  tambien participaron los ot...  palacios       es
# 4  fue el momento en que desde las tribunas se de...  palacios       es
#
#             publishedAt Label  sentiment_score sentiment_label
# 0  2023-01-29T18:25:03Z   NaN         0.468314         neutral
# 1  2023-01-31T20:41:38Z   NaN         0.996520        positive
# 2  2023-02-09T18:32:38Z   NaN         0.926711        positive
# 3  2023-02-12T21:13:55Z   NaN         0.961068        positive
# 4  2023-02-13T01:05:15Z   NaN         0.988847        positive

# %%
# Calculate the accuracy
accuracy = (df1['sentiment_label'] == df1['Label']).mean() * 100

# Print the accuracy
print("Accuracy: {:.2f}%".format(accuracy))
# Out:
# Accuracy: 4.22%

# %%
# Perform sentiment analysis on the DataFrame
df2 = perform_comparison_sentiment_analysis(df_es, sentiment_classifier2)

# Print the updated DataFrame
df2.head()
# Out:
#                                                 data    player language  \
# 0  adeyemi firmo el que es su primer gol en lo qu...  palacios       es
# 1  el club aleman, que siempre se ha caracterizad...  palacios       es
# 2  alberto fernandez  el presidente de la afa, cl...  palacios       es
# 3  alberto fernandez  tambien participaron los ot...  palacios       es
# 4  fue el momento en que desde las tribunas se de...  palacios       es
#
#             publishedAt Label  sentiment_score sentiment_label
# 0  2023-01-29T18:25:03Z   NaN         0.533805         neutral
# 1  2023-01-31T20:41:38Z   NaN         0.546071         neutral
# 2  2023-02-09T18:32:38Z   NaN         0.534002         neutral
# 3  2023-02-12T21:13:55Z   NaN         0.510552         neutral
# 4  2023-02-13T01:05:15Z   NaN         0.527243         neutral

# %%
# Calculate the accuracy
accuracy = (df2['sentiment_label'] == df2['Label']).mean() * 100

# Print the accuracy
print("Accuracy: {:.2f}%".format(accuracy))
# Out:
# Accuracy: 4.22%

# %% [markdown]
# ## Model 1

# %%
# Perform sentiment analysis on the DataFrame
df = perform_comparison_sentiment_analysis(df_es, sentiment_classifier1)

# Print the updated DataFrame
df.head()
# Out:
#                                                 data    player language  \
# 0  adeyemi firmo el que es su primer gol en lo qu...  palacios       es
# 1  el club aleman, que siempre se ha caracterizad...  palacios       es
# 2  alberto fernandez  el presidente de la afa, cl...  palacios       es
# 3  alberto fernandez  tambien participaron los ot...  palacios       es
# 4  fue el momento en que desde las tribunas se de...  palacios       es
#
#             publishedAt Label  sentiment_score sentiment_label
# 0  2023-01-29T18:25:03Z   NaN         0.468314         negativ
# 1  2023-01-31T20:41:38Z   NaN         0.996520         positiv
# 2  2023-02-09T18:32:38Z   NaN         0.926711         positiv
# 3  2023-02-12T21:13:55Z   NaN         0.961068         positiv
# 4  2023-02-13T01:05:15Z   NaN         0.988847         positiv

# %%
df[df['sentiment_label'] == 'negativ'].shape[0]/df.shape[0]
# Out:
# 0.004219409282700422

# %%
print(df['sentiment_label'].unique())
print(df['sentiment_score'].min())
print(df['sentiment_score'].max())
# Out:
# ['negativ' 'positiv']
# 0.46831411123275757
# 0.9988766312599182

# %%
# Drop rows where 'Label' is NaN or empty
df_es.dropna(subset=['Label'], inplace=True)

# Print the updated DataFrame
data = df_es[df_es['Label'] != 'neutral']

df_es
# Out:
#                                                   data    player language  \
# 6    wirtz, a la derecha, celebra su gol, el primer...  palacios       es
# 8     en tanto, palacios volvio al gol luego de sei...  palacios       es
# 18   panama y curazao con, como era previsible, los...  palacios       es
# 28    palacios marco este domingo dos goles ante ba...  palacios       es
# 48   luego ingresaron paulo dybala, juan foyth, rod...  palacios       es
# 52   palacios, el campeon de la seleccion argentina...  palacios       es
# 53   en sus historias de instagram, frias dejo entr...  palacios       es
# 54    luego de la publicacion que hizo yesica frias...  palacios       es
# 58   alexis mac allister intentara acercar a bright...  palacios       es
# 78   ademas, alphonso davies aparecio para despejar...  frimpong       es
# 80   frimpong\xaaparecio dentro del area para defin...  frimpong       es
# 82   el delantero nigeriano eludio rivales, se cayo...  frimpong       es
# 94   con canet, gilles lellouche, vincent cassel, m...       tah       es
# 100   sardar azmoun empato el partido, a los minuto...    bakker       es
# 105  a los , bakker consiguio poner la segunda anot...    bakker       es
# 107                (bakker, ')  andrich (amarilla, ')     bakker       es
# 125  en el duelo de vuelta, el equipo dirigido por ...     diaby       es
# 127        el gol de diaby les alejaba de la semifinal     diaby       es
# 129  a menudo el carrilero/lateral (frimpong) ocupa...     diaby       es
# 131  pero hay mas jugadores franceses en la agenda,...     diaby       es
# 143  tambien llegaron mudryk (), benoit badiashile ...    mudryk       es
# 145   sin embargo, las palabras del tecnico blue su...    mudryk       es
# 150  desde su desembarco este pasado verano en el c...    mudryk       es
# 178  en ecuador se espera que el defensa hincapie t...  hincapie       es
# 179  las familias controladoras no estan todas de a...  hincapie       es
# 181  el ecuatoriano\xapiero hincapie\xaarranco de t...  hincapie       es
# 218  el ecuatoriano hincapie fue titular en el partido  hincapie       es
# 225  un primo del futbolista ecuatoriano hincapie f...  hincapie       es
# 227  hincapie dio una asistencia y luego salio expu...  hincapie       es
# 233  el elenco aleman, del zaguero ecuatoriano hinc...  hincapie       es
#
#               publishedAt    Label  sentiment_score sentiment_label
# 6    2023-02-23T20:37:20Z  positiv         0.555995         positiv
# 8    2023-02-23T23:30:42Z  positiv         0.922271         positiv
# 18   2023-03-11T17:05:53Z  neutral         0.672797         positiv
# 28   2023-03-19T20:19:09Z  positiv         0.623142         positiv
# 48   2023-03-29T02:18:28Z  neutral         0.997254         positiv
# 52   2023-04-06T12:09:42Z  negativ         0.982327         positiv
# 53   2023-04-07T23:07:30Z  negativ         0.981422         positiv
# 54   2023-04-08T14:28:00Z  negativ         0.998399         positiv
# 58   2023-04-29T03:41:10Z  neutral         0.979650         positiv
# 78   2023-03-19T21:50:51Z  positiv         0.998621         positiv
# 80   2023-04-01T16:20:30Z  positiv         0.900498         positiv
# 82   2023-04-13T21:28:24Z  positiv         0.867035         positiv
# 94   2023-02-03T07:35:00Z  neutral         0.998749         positiv
# 100  2023-02-26T17:11:43Z  positiv         0.819514         positiv
# 105  2023-04-20T21:58:46Z  positiv         0.912903         positiv
# 107  2023-05-11T21:19:51Z  neutral         0.997140         positiv
# 125  2023-04-20T21:55:59Z  positiv         0.848503         positiv
# 127  2023-04-22T20:26:54Z  negativ         0.929652         positiv
# 129  2023-04-30T05:23:36Z  neutral         0.770632         positiv
# 131  2023-05-05T16:56:56Z  neutral         0.968608         positiv
# 143  2023-02-02T04:00:00Z  neutral         0.998390         positiv
# 145  2023-02-02T17:38:10Z  negativ         0.798171         positiv
# 150  2023-02-13T15:10:29Z  negativ         0.776657         positiv
# 178  2023-04-13T14:57:13Z  neutral         0.969772         positiv
# 179  2023-04-10T12:13:21Z  negativ         0.970278         positiv
# 181  2023-04-01T16:20:30Z  neutral         0.997835         positiv
# 218  2023-02-16T22:09:36Z  positiv         0.979099         positiv
# 225  2023-05-26T22:59:28Z  negativ         0.918628         positiv
# 227  2023-05-21T21:25:07Z  negativ         0.993751         positiv
# 233  2023-05-11T20:56:21Z  negativ         0.792746         positiv

# %%
data
# Out:
#                                                   data    player language  \
# 6    wirtz, a la derecha, celebra su gol, el primer...  palacios       es
# 8     en tanto, palacios volvio al gol luego de sei...  palacios       es
# 28    palacios marco este domingo dos goles ante ba...  palacios       es
# 52   palacios, el campeon de la seleccion argentina...  palacios       es
# 53   en sus historias de instagram, frias dejo entr...  palacios       es
# 54    luego de la publicacion que hizo yesica frias...  palacios       es
# 78   ademas, alphonso davies aparecio para despejar...  frimpong       es
# 80   frimpong\xaaparecio dentro del area para defin...  frimpong       es
# 82   el delantero nigeriano eludio rivales, se cayo...  frimpong       es
# 100   sardar azmoun empato el partido, a los minuto...    bakker       es
# 105  a los , bakker consiguio poner la segunda anot...    bakker       es
# 125  en el duelo de vuelta, el equipo dirigido por ...     diaby       es
# 127        el gol de diaby les alejaba de la semifinal     diaby       es
# 145   sin embargo, las palabras del tecnico blue su...    mudryk       es
# 150  desde su desembarco este pasado verano en el c...    mudryk       es
# 179  las familias controladoras no estan todas de a...  hincapie       es
# 218  el ecuatoriano hincapie fue titular en el partido  hincapie       es
# 225  un primo del futbolista ecuatoriano hincapie f...  hincapie       es
# 227  hincapie dio una asistencia y luego salio expu...  hincapie       es
# 233  el elenco aleman, del zaguero ecuatoriano hinc...  hincapie       es
#
#               publishedAt    Label  sentiment_score sentiment_label
# 6    2023-02-23T20:37:20Z  positiv         0.555995         positiv
# 8    2023-02-23T23:30:42Z  positiv         0.922271         positiv
# 28   2023-03-19T20:19:09Z  positiv         0.623142         positiv
# 52   2023-04-06T12:09:42Z  negativ         0.982327         positiv
# 53   2023-04-07T23:07:30Z  negativ         0.981422         positiv
# 54   2023-04-08T14:28:00Z  negativ         0.998399         positiv
# 78   2023-03-19T21:50:51Z  positiv         0.998621         positiv
# 80   2023-04-01T16:20:30Z  positiv         0.900498         positiv
# 82   2023-04-13T21:28:24Z  positiv         0.867035         positiv
# 100  2023-02-26T17:11:43Z  positiv         0.819514         positiv
# 105  2023-04-20T21:58:46Z  positiv         0.912903         positiv
# 125  2023-04-20T21:55:59Z  positiv         0.848503         positiv
# 127  2023-04-22T20:26:54Z  negativ         0.929652         positiv
# 145  2023-02-02T17:38:10Z  negativ         0.798171         positiv
# 150  2023-02-13T15:10:29Z  negativ         0.776657         positiv
# 179  2023-04-10T12:13:21Z  negativ         0.970278         positiv
# 218  2023-02-16T22:09:36Z  positiv         0.979099         positiv
# 225  2023-05-26T22:59:28Z  negativ         0.918628         positiv
# 227  2023-05-21T21:25:07Z  negativ         0.993751         positiv
# 233  2023-05-11T20:56:21Z  negativ         0.792746         positiv

# %%
# Calculate the accuracy
accuracy = (data['sentiment_label'] == data['Label']).mean() * 100

# Print the accuracy
print("Accuracy: {:.2f}%".format(accuracy))
# Out:
# Accuracy: 50.00%

# %%
# Assuming you have the true labels in 'Label' column and predicted labels in 'sentiment_label' column of the DataFrame
true_labels = data['Label']
predicted_labels = data['sentiment_label']

# Create the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Convert the confusion matrix to a DataFrame for better visualization
labels = np.unique(np.concatenate((true_labels, predicted_labels)))
cm_df = pd.DataFrame(cm, index=labels, columns=labels)

# Display the confusion matrix
print("Confusion Matrix:")
print(cm_df)
# Out:
# Confusion Matrix:
#          negativ  positiv
# negativ        0       10
# positiv        0       10

# %%
# Assuming you have the true labels in 'Label' column and predicted labels in 'sentiment_label' column of the DataFrame
true_labels = data['Label']
predicted_labels = data['sentiment_label']

# Generate the classification report
report = classification_report(true_labels, predicted_labels)

# Display the classification report
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      negativ       0.00      0.00      0.00        10
#      positiv       0.50      1.00      0.67        10
#
#     accuracy                           0.50        20
#    macro avg       0.25      0.50      0.33        20
# weighted avg       0.25      0.50      0.33        20
# C:\Users\joana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\joana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\joana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Model 2

# %%
# Perform sentiment analysis on the DataFrame
df = perform_comparison_sentiment_analysis(df_es, sentiment_classifier2)

# Print the updated DataFrame
df.head()
# Out:
#                                                  data    player language  \
# 6   wirtz, a la derecha, celebra su gol, el primer...  palacios       es
# 8    en tanto, palacios volvio al gol luego de sei...  palacios       es
# 18  panama y curazao con, como era previsible, los...  palacios       es
# 28   palacios marco este domingo dos goles ante ba...  palacios       es
# 48  luego ingresaron paulo dybala, juan foyth, rod...  palacios       es
#
#              publishedAt    Label  sentiment_score sentiment_label
# 6   2023-02-23T20:37:20Z  positiv         0.546026         positiv
# 8   2023-02-23T23:30:42Z  positiv         0.570668         positiv
# 18  2023-03-11T17:05:53Z  neutral         0.539131         positiv
# 28  2023-03-19T20:19:09Z  positiv         0.565715         positiv
# 48  2023-03-29T02:18:28Z  neutral         0.588336         positiv

# %%
df[df['sentiment_label'] == 'negativ'].shape[0]/df.shape[0]
# Out:
# 0.0

# %%
# Drop rows where 'Label' is NaN or empty
df_es.dropna(subset=['Label'], inplace=True)

# Print the updated DataFrame
data = df_es[df_es['Label'] != 'neutral']

df_es
# Out:
#                                                   data    player language  \
# 6    wirtz, a la derecha, celebra su gol, el primer...  palacios       es
# 8     en tanto, palacios volvio al gol luego de sei...  palacios       es
# 18   panama y curazao con, como era previsible, los...  palacios       es
# 28    palacios marco este domingo dos goles ante ba...  palacios       es
# 48   luego ingresaron paulo dybala, juan foyth, rod...  palacios       es
# 52   palacios, el campeon de la seleccion argentina...  palacios       es
# 53   en sus historias de instagram, frias dejo entr...  palacios       es
# 54    luego de la publicacion que hizo yesica frias...  palacios       es
# 58   alexis mac allister intentara acercar a bright...  palacios       es
# 78   ademas, alphonso davies aparecio para despejar...  frimpong       es
# 80   frimpong\xaaparecio dentro del area para defin...  frimpong       es
# 82   el delantero nigeriano eludio rivales, se cayo...  frimpong       es
# 94   con canet, gilles lellouche, vincent cassel, m...       tah       es
# 100   sardar azmoun empato el partido, a los minuto...    bakker       es
# 105  a los , bakker consiguio poner la segunda anot...    bakker       es
# 107                (bakker, ')  andrich (amarilla, ')     bakker       es
# 125  en el duelo de vuelta, el equipo dirigido por ...     diaby       es
# 127        el gol de diaby les alejaba de la semifinal     diaby       es
# 129  a menudo el carrilero/lateral (frimpong) ocupa...     diaby       es
# 131  pero hay mas jugadores franceses en la agenda,...     diaby       es
# 143  tambien llegaron mudryk (), benoit badiashile ...    mudryk       es
# 145   sin embargo, las palabras del tecnico blue su...    mudryk       es
# 150  desde su desembarco este pasado verano en el c...    mudryk       es
# 178  en ecuador se espera que el defensa hincapie t...  hincapie       es
# 179  las familias controladoras no estan todas de a...  hincapie       es
# 181  el ecuatoriano\xapiero hincapie\xaarranco de t...  hincapie       es
# 218  el ecuatoriano hincapie fue titular en el partido  hincapie       es
# 225  un primo del futbolista ecuatoriano hincapie f...  hincapie       es
# 227  hincapie dio una asistencia y luego salio expu...  hincapie       es
# 233  el elenco aleman, del zaguero ecuatoriano hinc...  hincapie       es
#
#               publishedAt    Label  sentiment_score sentiment_label
# 6    2023-02-23T20:37:20Z  positiv         0.546026         positiv
# 8    2023-02-23T23:30:42Z  positiv         0.570668         positiv
# 18   2023-03-11T17:05:53Z  neutral         0.539131         positiv
# 28   2023-03-19T20:19:09Z  positiv         0.565715         positiv
# 48   2023-03-29T02:18:28Z  neutral         0.588336         positiv
# 52   2023-04-06T12:09:42Z  negativ         0.529579         positiv
# 53   2023-04-07T23:07:30Z  negativ         0.503963         positiv
# 54   2023-04-08T14:28:00Z  negativ         0.535089         positiv
# 58   2023-04-29T03:41:10Z  neutral         0.570315         positiv
# 78   2023-03-19T21:50:51Z  positiv         0.510269         positiv
# 80   2023-04-01T16:20:30Z  positiv         0.539357         positiv
# 82   2023-04-13T21:28:24Z  positiv         0.502849         positiv
# 94   2023-02-03T07:35:00Z  neutral         0.588503         positiv
# 100  2023-02-26T17:11:43Z  positiv         0.527136         positiv
# 105  2023-04-20T21:58:46Z  positiv         0.521956         positiv
# 107  2023-05-11T21:19:51Z  neutral         0.547199         positiv
# 125  2023-04-20T21:55:59Z  positiv         0.523610         positiv
# 127  2023-04-22T20:26:54Z  negativ         0.587055         positiv
# 129  2023-04-30T05:23:36Z  neutral         0.541256         positiv
# 131  2023-05-05T16:56:56Z  neutral         0.507464         positiv
# 143  2023-02-02T04:00:00Z  neutral         0.506183         positiv
# 145  2023-02-02T17:38:10Z  negativ         0.564526         positiv
# 150  2023-02-13T15:10:29Z  negativ         0.571498         positiv
# 178  2023-04-13T14:57:13Z  neutral         0.517209         positiv
# 179  2023-04-10T12:13:21Z  negativ         0.531143         positiv
# 181  2023-04-01T16:20:30Z  neutral         0.551997         positiv
# 218  2023-02-16T22:09:36Z  positiv         0.583366         positiv
# 225  2023-05-26T22:59:28Z  negativ         0.504521         positiv
# 227  2023-05-21T21:25:07Z  negativ         0.501494         positiv
# 233  2023-05-11T20:56:21Z  negativ         0.598143         positiv

# %%
data
# Out:
#                                                   data    player language  \
# 6    wirtz, a la derecha, celebra su gol, el primer...  palacios       es
# 8     en tanto, palacios volvio al gol luego de sei...  palacios       es
# 28    palacios marco este domingo dos goles ante ba...  palacios       es
# 52   palacios, el campeon de la seleccion argentina...  palacios       es
# 53   en sus historias de instagram, frias dejo entr...  palacios       es
# 54    luego de la publicacion que hizo yesica frias...  palacios       es
# 78   ademas, alphonso davies aparecio para despejar...  frimpong       es
# 80   frimpong\xaaparecio dentro del area para defin...  frimpong       es
# 82   el delantero nigeriano eludio rivales, se cayo...  frimpong       es
# 100   sardar azmoun empato el partido, a los minuto...    bakker       es
# 105  a los , bakker consiguio poner la segunda anot...    bakker       es
# 125  en el duelo de vuelta, el equipo dirigido por ...     diaby       es
# 127        el gol de diaby les alejaba de la semifinal     diaby       es
# 145   sin embargo, las palabras del tecnico blue su...    mudryk       es
# 150  desde su desembarco este pasado verano en el c...    mudryk       es
# 179  las familias controladoras no estan todas de a...  hincapie       es
# 218  el ecuatoriano hincapie fue titular en el partido  hincapie       es
# 225  un primo del futbolista ecuatoriano hincapie f...  hincapie       es
# 227  hincapie dio una asistencia y luego salio expu...  hincapie       es
# 233  el elenco aleman, del zaguero ecuatoriano hinc...  hincapie       es
#
#               publishedAt    Label  sentiment_score sentiment_label
# 6    2023-02-23T20:37:20Z  positiv         0.546026         positiv
# 8    2023-02-23T23:30:42Z  positiv         0.570668         positiv
# 28   2023-03-19T20:19:09Z  positiv         0.565715         positiv
# 52   2023-04-06T12:09:42Z  negativ         0.529579         positiv
# 53   2023-04-07T23:07:30Z  negativ         0.503963         positiv
# 54   2023-04-08T14:28:00Z  negativ         0.535089         positiv
# 78   2023-03-19T21:50:51Z  positiv         0.510269         positiv
# 80   2023-04-01T16:20:30Z  positiv         0.539357         positiv
# 82   2023-04-13T21:28:24Z  positiv         0.502849         positiv
# 100  2023-02-26T17:11:43Z  positiv         0.527136         positiv
# 105  2023-04-20T21:58:46Z  positiv         0.521956         positiv
# 125  2023-04-20T21:55:59Z  positiv         0.523610         positiv
# 127  2023-04-22T20:26:54Z  negativ         0.587055         positiv
# 145  2023-02-02T17:38:10Z  negativ         0.564526         positiv
# 150  2023-02-13T15:10:29Z  negativ         0.571498         positiv
# 179  2023-04-10T12:13:21Z  negativ         0.531143         positiv
# 218  2023-02-16T22:09:36Z  positiv         0.583366         positiv
# 225  2023-05-26T22:59:28Z  negativ         0.504521         positiv
# 227  2023-05-21T21:25:07Z  negativ         0.501494         positiv
# 233  2023-05-11T20:56:21Z  negativ         0.598143         positiv

# %%
# Calculate the accuracy
accuracy = (data['sentiment_label'] == data['Label']).mean() * 100

# Print the accuracy
print("Accuracy: {:.2f}%".format(accuracy))
# Out:
# Accuracy: 50.00%

# %%
data.head()
# Out:
#                                                  data    player language  \
# 6   wirtz, a la derecha, celebra su gol, el primer...  palacios       es
# 8    en tanto, palacios volvio al gol luego de sei...  palacios       es
# 28   palacios marco este domingo dos goles ante ba...  palacios       es
# 52  palacios, el campeon de la seleccion argentina...  palacios       es
# 53  en sus historias de instagram, frias dejo entr...  palacios       es
#
#              publishedAt    Label  sentiment_score sentiment_label
# 6   2023-02-23T20:37:20Z  positiv         0.546026         positiv
# 8   2023-02-23T23:30:42Z  positiv         0.570668         positiv
# 28  2023-03-19T20:19:09Z  positiv         0.565715         positiv
# 52  2023-04-06T12:09:42Z  negativ         0.529579         positiv
# 53  2023-04-07T23:07:30Z  negativ         0.503963         positiv

# %%
# Assuming you have the true labels in 'Label' column and predicted labels in 'sentiment_label' column of the DataFrame
true_labels = data['Label']
predicted_labels = data['sentiment_label']

# Create the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Convert the confusion matrix to a DataFrame for better visualization
labels = np.unique(np.concatenate((true_labels, predicted_labels)))
cm_df = pd.DataFrame(cm, index=labels, columns=labels)

# Display the confusion matrix
print("Confusion Matrix:")
print(cm_df)
# Out:
# Confusion Matrix:
#          negativ  positiv
# negativ        0       10
# positiv        0       10

# %%
# Assuming you have the true labels in 'Label' column and predicted labels in 'sentiment_label' column of the DataFrame
true_labels = data['Label']
predicted_labels = data['sentiment_label']

# Generate the classification report
report = classification_report(true_labels, predicted_labels)

# Display the classification report
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      negativ       0.00      0.00      0.00        10
#      positiv       0.50      1.00      0.67        10
#
#     accuracy                           0.50        20
#    macro avg       0.25      0.50      0.33        20
# weighted avg       0.25      0.50      0.33        20
# C:\Users\joana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\joana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\joana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
