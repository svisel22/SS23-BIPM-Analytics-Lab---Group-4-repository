# %%
import pprint
import requests
from newsapi import NewsApiClient
import datetime
import matplotlib.pyplot as plt
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np

secret = '40d4a2e1919c4066b59df69ca787f4ba'
  
# Define the endpoint
url = 'https://newsapi.org/v2/everything'


# Get today's date
today = datetime.date.today()

# Get the date 2 years ago
two_years = today - datetime.timedelta(days=30)

# %%
def get_articlesplayer(player, language):

    url = 'https://newsapi.org/v2/everything'

    # Create date_form and to for the last month
    today = datetime.date.today()
    date_from = today.strftime("%Y-%m-%d")
    date_to = today - datetime.timedelta(days=31)
    date_to = date_to.strftime("%Y-%m-%d")

    # Specify the query and number of returns
    parameters_bakker = {
        'q': player, # query phrase
        'pageSize': 100,  # maximum is 100
        'apiKey': secret, # your own API key
        'sortBy':'publishedAt',
        'from': date_from,
        'to': date_to, 
        'language': language
    }

    response = requests.get(url, params = parameters_bakker)

    # Parse the JSON response and extract article URLs
    if response.ok:
        data = response.json()
        urls = [article['url'] for article in data['articles']]
    else:
        print('Error: Request failed with status', response.status_code)

    # Scrape the full article content for each URL and store in a dataframe
    articles = []
    for url in urls:
        # Make a request to the article URL
        response = requests.get(url)

        # Parse the HTML response and extract the article content
        if response.ok:
            soup = BeautifulSoup(response.content, 'html.parser')
        
            content = '\n'.join([p.text.strip() for p in soup.find_all('p')])
            articles.append({'content': content})
        else:
            print('Error: Request failed with status', response.status_code)


    # Convert the list of articles to a Pandas dataframe
    df = pd.DataFrame(articles)

    return(articles)

# %%
def get_players_df(playerlist, languagelist):

    df_all_players = pd.DataFrame(columns=['data', 'player', 'language'])

    # Loop over players and given languages
    for player in playerlist:

        for language in languagelist:

            articles_arr = get_articlesplayer(player, language)

            language_arr = np.full((len(articles_arr)), language)

            player_arr = np.full((len(articles_arr)), player)

            df_one_lang = pd.DataFrame({'data': articles_arr, 'player': player_arr,'language': language_arr})

            df_all_players = pd.concat([df_all_players, df_one_lang])

    return df_all_players

# %%
playerlist = ['Mitchel Bakker', 'Jeremie Frimpong', 'Moussa Diaby', 'Jonathan Tah', 'Piero Hincapie', 'Exequiel Palacios', 'Mykhaylo Mudryk'] 
languagelist = ['en', 'de', 'es']
df_all = get_players_df(playerlist, languagelist)
# Out:
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 404
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 403
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 429
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb Zelle 4 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> playerlist = ['Mitchel Bakker', 'Jeremie Frimpong', 'Moussa Diaby', 'Jonathan Tah', 'Piero Hincapie', 'Exequiel Palacios', 'Mykhaylo Mudryk']
#       <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> languagelist = ['en', 'de', 'es']
# ----> <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> df_all = get_players_df(playerlist, languagelist)
#
# /Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb Zelle 4 in get_players_df(playerlist, languagelist)
#       <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X20sZmlsZQ%3D%3D?line=5'>6</a> for player in playerlist:
#       <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a>     for language in languagelist:
# ---> <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X20sZmlsZQ%3D%3D?line=9'>10</a>         articles_arr = get_articlesplayer(player, language)
#      <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X20sZmlsZQ%3D%3D?line=11'>12</a>         language_arr = np.full((len(articles_arr)), language)
#      <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X20sZmlsZQ%3D%3D?line=13'>14</a>         player_arr = np.full((len(articles_arr)), player)
#
# /Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb Zelle 4 in get_articlesplayer(player, language)
#      <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X20sZmlsZQ%3D%3D?line=30'>31</a> # Scrape the full article content for each URL and store in a dataframe
#      <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X20sZmlsZQ%3D%3D?line=31'>32</a> articles = []
# ---> <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X20sZmlsZQ%3D%3D?line=32'>33</a> for url in urls:
#      <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X20sZmlsZQ%3D%3D?line=33'>34</a>     # Make a request to the article URL
#      <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X20sZmlsZQ%3D%3D?line=34'>35</a>     response = requests.get(url)
#      <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X20sZmlsZQ%3D%3D?line=36'>37</a>     # Parse the HTML response and extract the article content
#
# UnboundLocalError: local variable 'urls' referenced before assignment

# %% [markdown]
# Next Function not finished already

# %%
def updateplayerdata():
    df_old_player_data = pd.read_csv('/Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/data_files/all_data.csv')
    
    playerlist = ['Mitchel Bakker', 'Jeremie Frimpong', 'Moussa Diaby', 'Jonathan Tah', 'Piero Hincapie', 'Exequiel Palacios', 'Mykhaylo Mudryk'] 
    languagelist = ['en', 'de', 'es']
    df_all_lastmonth = get_players_df(playerlist, languagelist)

##### just testing 
    test_df = pd.DataFrame({'data': ['test1', 'test2'], 'player': ['test1', 'test2'], 'language': ['test1', 'test2']})
    df_all_lastmonth = pd.concat([df_all_lastmonth, test_df], axis =0)
#####
    df_all_lastmonth = df_all_lastmonth.reindex(sorted(df_all_lastmonth.columns), axis=1)
    df_old_player_data = df.reindex(sorted(df_old_player_data.columns), axis=1)
    df_old_player_data = df_old_player_data.reindex(df_all_lastmonth.index)

    df_new =  df_old_player_data.compare(df_all_lastmonth)

    # Open the CSV file in append mode and write the DataFrame
    with open('/Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/data_files/all_data.csv', 'a', newline='') as f:
        df_new.to_csv(f, header=f.tell()==0, index=False)
    
    return('Players updated')

# %%
updateplayerdata()
# Out:
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 404
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 403
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 403
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 404
# Error: Request failed with status 429
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb Zelle 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X63sZmlsZQ%3D%3D?line=0'>1</a> updateplayerdata()
#
# /Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb Zelle 6 in updateplayerdata()
#       <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X63sZmlsZQ%3D%3D?line=3'>4</a>     playerlist = ['Mitchel Bakker', 'Jeremie Frimpong', 'Moussa Diaby', 'Jonathan Tah', 'Piero Hincapie', 'Exequiel Palacios', 'Mykhaylo Mudryk']
#       <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X63sZmlsZQ%3D%3D?line=4'>5</a>     languagelist = ['en', 'de', 'es']
# ----> <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X63sZmlsZQ%3D%3D?line=5'>6</a>     df_all_lastmonth = get_players_df(playerlist, languagelist)
#       <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X63sZmlsZQ%3D%3D?line=7'>8</a> ##### just testing
#       <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X63sZmlsZQ%3D%3D?line=8'>9</a>     test_df = pd.DataFrame({'data': ['test1', 'test2'], 'player': ['test1', 'test2'], 'language': ['test1', 'test2']})
#
# /Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb Zelle 6 in get_players_df(playerlist, languagelist)
#       <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X63sZmlsZQ%3D%3D?line=5'>6</a> for player in playerlist:
#       <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X63sZmlsZQ%3D%3D?line=7'>8</a>     for language in languagelist:
# ---> <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X63sZmlsZQ%3D%3D?line=9'>10</a>         articles_arr = get_articlesplayer(player, language)
#      <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X63sZmlsZQ%3D%3D?line=11'>12</a>         language_arr = np.full((len(articles_arr)), language)
#      <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X63sZmlsZQ%3D%3D?line=13'>14</a>         player_arr = np.full((len(articles_arr)), player)
#
# /Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb Zelle 6 in get_articlesplayer(player, language)
#      <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X63sZmlsZQ%3D%3D?line=30'>31</a> # Scrape the full article content for each URL and store in a dataframe
#      <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X63sZmlsZQ%3D%3D?line=31'>32</a> articles = []
# ---> <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X63sZmlsZQ%3D%3D?line=32'>33</a> for url in urls:
#      <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X63sZmlsZQ%3D%3D?line=33'>34</a>     # Make a request to the article URL
#      <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X63sZmlsZQ%3D%3D?line=34'>35</a>     response = requests.get(url)
#      <a href='vscode-notebook-cell:/Users/kevingiesen/Library/Mobile%20Documents/com~apple~CloudDocs/BIPM%20Master/Semester%202/TWSM/TWSM%20Project/SS23-BIPM-Analytics-Lab---Group-4-repository/test_kevin.ipynb#X63sZmlsZQ%3D%3D?line=36'>37</a>     # Parse the HTML response and extract the article content
#
# UnboundLocalError: local variable 'urls' referenced before assignment
