# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import requests
from bs4 import BeautifulSoup
import re
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# # Load Data

# %%
# Load the CSV file into a DataFrame
#ACTION:Why doesn't this work for me? I checked the link so often and the one below works.
df_de = pd.read_csv('../Preprocessing/data_clean/labeled-data/labeled-de_clean_1-1.csv', sep=';')

# %%
# Load the CSV file into a DataFrame
df_de_con = pd.read_csv('../Preprocessing/data_clean/labeled-data/labeled-de_clean_condensed.csv', sep=';')

# %%
df_de_con.head()
# Out:
#                                                 data             player  \
# 0  trainer alonso mitgereisten fans monaco glucks...  exequiel palacios
# 1  sechser droht viereinhalb monaten pause bitter...  exequiel palacios
# 2  bayerleverkusen sechser erklart budapest spiel...  exequiel palacios
# 3  bakker mittwoch abschluss training bayerleverk...  exequiel palacios
# 4  allerdings andrich argentinischen weltmeister ...  exequiel palacios
#
#   language           publishedAt    Label
# 0       de  2023-02-24T09:33:31Z  positiv
# 1       de  2023-03-03T21:35:13Z      NaN
# 2       de  2023-03-07T11:34:39Z      NaN
# 3       de  2023-03-08T14:25:18Z      NaN
# 4       de  2023-03-09T19:53:46Z      NaN

# %% [markdown]
# ### Fix DE

# %%
#for DE datasate drop empty lines
df_de = df_de.dropna(subset=['data']) #Why in data and not in Label column?

# %% [markdown]
# # Sentiment analysis full text

# %%
def perform_sentiment_analysis(df):
    # Load the tokenizer and model
    tokenizer = AutoTokenizer.from_pretrained("oliverguhr/german-sentiment-bert")
    model = AutoModelForSequenceClassification.from_pretrained("oliverguhr/german-sentiment-bert")

    # Create an empty list to store the sentiment scores
    sentiment_scores = []

    # Iterate over the 'data' column in the DataFrame
    for text in df['data']:
        # Tokenize the input text
        tokens = tokenizer.encode_plus(text, padding="max_length", truncation=True, max_length=128,
                                       return_tensors="pt")

        # Perform the sentiment analysis
        with torch.no_grad():
            logits = model(**tokens)[0]

        # Convert logits to predicted label (positive/negative)
        predicted_label = torch.argmax(logits, dim=1).item()
        sentiment = "positiv" if predicted_label == 1 else "negativ"

        # Append the sentiment score to the list
        sentiment_scores.append(sentiment)

    # Add the sentiment scores as a new column in the DataFrame
    df['sentiment'] = sentiment_scores

    return df

# %% [markdown]
# ## d1-1

# %%
# Perform sentiment analysis on the DataFrame
df = perform_sentiment_analysis(df_de)

# Print the updated DataFrame
df.head()
# Out:
#                                                 data    player language  \
# 0  trainer alonso vor den mitgereisten fans in mo...  palacios       de
# 1  zudem ist die konkurrenzsituation auf der dopp...  palacios       de
# 2  wie auch palacios sah der defensive mittelfeld...  palacios       de
# 3  ,,er ist eine option", erklart alonso, der im ...  palacios       de
# 4     allerdings waren in andrich und dem argenti...  palacios       de
#
#             publishedAt Label sentiment
# 0  2023-02-24T09:33:31Z   NaN   negativ
# 1  2023-03-03T21:35:13Z   NaN   negativ
# 2  2023-03-07T11:34:39Z   NaN   negativ
# 3  2023-03-08T14:25:18Z   NaN   negativ
# 4  2023-03-09T19:53:46Z   NaN   negativ

# %%
df[df['sentiment'] == 'negativ'].shape[0]/df.shape[0]
# Out:
# 0.9703872437357631

# %%
# Drop rows where 'Label' is NaN or empty
df_de.dropna(subset=['Label'], inplace=True)

# Print the updated DataFrame
data = df_de[df_de['Label'] != 'neutral']

df_de
# Out:
#                                                   data    player language  \
# 14   zweimal verwandelte palacios, es wurde ein ube...  palacios       de
# 23   schalke: reis nimmt den spieler ausdrucklich i...  palacios       de
# 31   palacios (r.) verletzte sich leicht im hinspie...  palacios       de
# 41   "auf jeden fall" sei das ein ganz grosser tag,...  palacios       de
# 58   beim abschlusstraining trug letzterer zumindes...  palacios       de
# 63   bayerleverkusen argentinischer weltmeister pal...  palacios       de
# 83   "es gibt im moment nicht viel besseres in der ...  frimpong       de
# 93   der fc bayern munchen interessiert sich nach i...  frimpong       de
# 95   frimpong hat noch bis vertrag in bayerleverkus...  frimpong       de
# 102  hincapie (l.) und tah bedanken sich fur die fa...  frimpong       de
# 120  diaby, wirtz, adam hlozek und frimpong teilten...  frimpong       de
# 123     bayerleverkusen torschutze amiri (rechts) u...  frimpong       de
# 124  frimpong bekommt gluckwunsche seines trainers ...  frimpong       de
# 130  selbst als stammkraft frimpong in den vergange...  frimpong       de
# 163  ohne hincapie und tah mussten wir entscheiden,...       tah       de
# 173  schalke wiederum hatte durch michael frey ein ...       tah       de
# 180   bayerleverkusen-coach alonso rotierte im verg...       tah       de
# 199  alonso "stolz": werkself seit spielen ungeschl...       tah       de
# 214  torwart lukas hradecky bewahrte bayerleverkuse...       tah       de
# 223  zudem drohen sowohl bakker\xaals auch weltmeis...    bakker       de
# 258  torschutzen unter sich: diaby (links, treffer ...    bakker       de
# 273               beim : hatte mitchell bakker gepatzt    bakker       de
# 334                        minute uber wirtz und diaby     diaby       de
# 355  das team wird zudem von den beiden bayerleverk...     diaby       de
# 361  frimpong wirkt uberspielt, und diaby bewegte s...     diaby       de
# 362  torwart lukas hradecky bewahrte bayerleverkuse...     diaby       de
# 383  zu sehen ist davon wenig - und das liegt nicht...    mudryk       de
# 413  hincapie von fussball-bundesligist bayerleverk...  hincapie       de
# 433  bayerleverkusen torwart lukas hradecky sitzt f...  hincapie       de
# 436  in der funften minute der nachspielzeit sah ba...  hincapie       de
#
#               publishedAt    Label sentiment
# 14   2023-03-19T20:01:45Z  positiv   negativ
# 23   2023-04-03T08:12:20Z  neutral   negativ
# 31   2023-04-17T06:50:19Z  neutral   negativ
# 41   2023-04-20T20:54:03Z  positiv   negativ
# 58   2023-05-17T11:20:50Z  neutral   negativ
# 63   2023-05-14T18:07:21Z  negativ   negativ
# 83   2023-03-31T07:59:57Z  positiv   negativ
# 93   2023-04-06T16:49:00Z  neutral   negativ
# 95   2023-04-07T07:42:27Z  neutral   negativ
# 102  2023-04-14T08:16:22Z  positiv   negativ
# 120  2023-04-21T10:02:05Z  neutral   negativ
# 123  2023-04-23T17:33:57Z  positiv   negativ
# 124  2023-04-23T18:00:31Z  positiv   negativ
# 130  2023-05-23T10:24:42Z  negativ   negativ
# 163  2023-02-27T15:54:01Z  neutral   positiv
# 173  2023-04-01T15:44:09Z  positiv   negativ
# 180  2023-04-16T19:29:40Z  neutral   negativ
# 199  2023-04-23T20:48:00Z  positiv   negativ
# 214  2023-05-11T23:42:49Z  positiv   negativ
# 223  2023-02-23T09:06:07Z  negativ   negativ
# 258  2023-04-20T21:15:24Z  positiv   negativ
# 273  2023-05-21T19:39:14Z  negativ   negativ
# 334  2023-04-29T15:37:30Z  neutral   positiv
# 355  2023-05-13T10:26:28Z  neutral   negativ
# 361  2023-05-12T09:44:10Z  negativ   negativ
# 362  2023-05-11T23:42:49Z  negativ   negativ
# 383  2023-04-19T06:10:46Z  negativ   negativ
# 413  2023-05-23T10:52:44Z  negativ   negativ
# 433  2023-02-17T17:14:46Z  negativ   negativ
# 436  2023-05-21T19:53:27Z  negativ   negativ

# %%
data.head()
# Out:
#                                                   data    player language  \
# 14   zweimal verwandelte palacios, es wurde ein ube...  palacios       de
# 41   "auf jeden fall" sei das ein ganz grosser tag,...  palacios       de
# 63   bayerleverkusen argentinischer weltmeister pal...  palacios       de
# 83   "es gibt im moment nicht viel besseres in der ...  frimpong       de
# 102  hincapie (l.) und tah bedanken sich fur die fa...  frimpong       de
#
#               publishedAt    Label sentiment
# 14   2023-03-19T20:01:45Z  positiv   negativ
# 41   2023-04-20T20:54:03Z  positiv   negativ
# 63   2023-05-14T18:07:21Z  negativ   negativ
# 83   2023-03-31T07:59:57Z  positiv   negativ
# 102  2023-04-14T08:16:22Z  positiv   negativ

# %%
# Calculate the accuracy
accuracy = (data['sentiment'] == data['Label']).mean() * 100

# Print the accuracy
print("Accuracy: {:.2f}%".format(accuracy))
# Out:
# Accuracy: 50.00%

# %%
print(data['sentiment'].unique())
# Out:
# ['negativ']

# %%
# Assuming you have the true labels in 'Label' column and predicted labels in 'sentiment_label' column of the DataFrame
true_labels = data['Label']
predicted_labels = data['sentiment']

# Create the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Convert the confusion matrix to a DataFrame for better visualization
labels = np.unique(np.concatenate((true_labels, predicted_labels)))
cm_df = pd.DataFrame(cm, index=labels, columns=labels)

# Display the confusion matrix
print("Confusion Matrix:")
print(cm_df)
# Out:
# Confusion Matrix:
#          negativ  positiv
# negativ       10        0
# positiv       10        0

# %%
# Assuming you have the true labels in 'Label' column and predicted labels in 'sentiment_label' column of the DataFrame
true_labels = data['Label']
predicted_labels = data['sentiment']

# Generate the classification report
report = classification_report(true_labels, predicted_labels)

# Display the classification report
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      negativ       0.50      1.00      0.67        10
#      positiv       0.00      0.00      0.00        10
#
#     accuracy                           0.50        20
#    macro avg       0.25      0.50      0.33        20
# weighted avg       0.25      0.50      0.33        20
# C:\Users\joana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\joana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\joana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## d_con

# %%
# Perform sentiment analysis on the DataFrame
df_con = perform_sentiment_analysis(df_de_con)

# Print the updated DataFrame
df_con.head()
# Out:
#                                                 data             player  \
# 0  trainer alonso mitgereisten fans monaco glucks...  exequiel palacios
# 1  sechser droht viereinhalb monaten pause bitter...  exequiel palacios
# 2  bayerleverkusen sechser erklart budapest spiel...  exequiel palacios
# 3  bakker mittwoch abschluss training bayerleverk...  exequiel palacios
# 4  allerdings andrich argentinischen weltmeister ...  exequiel palacios
#
#   language           publishedAt    Label sentiment
# 0       de  2023-02-24T09:33:31Z  positiv   negativ
# 1       de  2023-03-03T21:35:13Z      NaN   negativ
# 2       de  2023-03-07T11:34:39Z      NaN   positiv
# 3       de  2023-03-08T14:25:18Z      NaN   negativ
# 4       de  2023-03-09T19:53:46Z      NaN   negativ

# %%
df_con[df_con['sentiment'] == 'negativ'].shape[0]/df_con.shape[0]
# Out:
# 0.8901639344262295

# %%
# Drop rows where 'Label' is NaN or empty
df_de_con.dropna(subset=['Label'], inplace=True)

# Print the updated DataFrame
data_con = df_de_con[df_de_con['Label'] != 'neutral']

df_de_con
# Out:
#                                                   data             player  \
# 0    trainer alonso mitgereisten fans monaco glucks...  exequiel palacios
# 9    heisse begegnung bremen trotz fruhen fuhrungst...  exequiel palacios
# 29   dazn experte michael ballack gesprach julian n...  exequiel palacios
# 72   diesmal andrich entnervt angesprochen standige...  exequiel palacios
# 111  torschutzen sich wirtz jubeln tage wirtz darau...   jeremie frimpong
# 132  hincapie tah bedanken fan unterstutzung tolle ...   jeremie frimpong
# 148  bayerleverkusen vortanzer jubelt uber tor hins...   jeremie frimpong
# 162  bayerleverkusen torschutze amiri rechts jubeln...   jeremie frimpong
# 168  ganz entspannt fruhstuck amsterdam bayerleverk...   jeremie frimpong
# 170  bayerleverkusen verteidiger drei spiele gesper...   jeremie frimpong
# 191  andrich halbfinal hinspiel moglicherweise mitt...   jeremie frimpong
# 210  bayerleverkusen anfuhrer zentralen mittelfeld ...   jeremie frimpong
# 216  andrich uberzeugte freiburg abwehrchef moglich...       jonathan tah
# 227  torschutzen sich diaby adli feiern adlis treff...       jonathan tah
# 252  palacios verletzte leicht hinspiel saint gilloise       jonathan tah
# 314       marseille bayerleverkusen sturmer reserviert     mitchel bakker
# 351  torschutzen sich diaby links treffer bayerleve...     mitchel bakker
# 406  frankfurter erstmals gelbgesperrt mario gotze ...       moussa diaby
# 435  kapitan lukas hradecky stand mehr halbe stunde...       moussa diaby
# 457  hinrunde bekam rani khedira mittelfeldspieler ...       moussa diaby
# 497  sebastian hoeness brachte wahrsten sinne worte...       moussa diaby
# 505  bayerleverkusen vergibt leichtfertig gute ausg...       moussa diaby
# 527  mehr millionen euro boehly saison transferzahl...    mykhaylo mudryk
# 530  callum hudson odoi kehrt leihe chelsea zuruck ...     piero hincapie
# 562  fussball bundesligist bayerleverkusen roten ka...     piero hincapie
# 565  rolfes zurnt alonso warnt bochum effekt erkenn...     piero hincapie
# 576  frimpong bekommt gluckwunsche trainers alonso ...     piero hincapie
# 580  bayerleverkusen union berlin union saint gillo...     piero hincapie
# 596  bayerleverkusen torwart lukas hradecky sitzt f...     piero hincapie
# 604  daniel farke fuhlte unruhigen woche hektischen...     piero hincapie
#
#     language           publishedAt    Label sentiment
# 0         de  2023-02-24T09:33:31Z  positiv   negativ
# 9         de  2023-03-12T11:30:02Z  neutral   negativ
# 29        de  2023-03-20T13:16:11Z  neutral   negativ
# 72        de  2023-05-05T18:02:55Z  negativ   negativ
# 111       de  2023-04-02T12:05:20Z  positiv   negativ
# 132       de  2023-04-14T08:16:22Z  positiv   positiv
# 148       de  2023-04-20T21:02:06Z   positv   negativ
# 162       de  2023-04-23T17:33:57Z  positiv   negativ
# 168       de  2023-05-01T16:20:02Z  neutral   negativ
# 170       de  2023-05-23T10:24:42Z  negativ   negativ
# 191       de  2023-05-12T10:57:31Z  negativ   negativ
# 210       de  2023-05-10T16:52:59Z   neutal   negativ
# 216       de  2023-02-27T15:54:01Z  positiv   negativ
# 227       de  2023-03-17T07:01:04Z  positiv   negativ
# 252       de  2023-04-17T06:50:19Z  negativ   negativ
# 314       de  2023-02-27T10:00:11Z  neutral   positiv
# 351       de  2023-04-20T21:15:24Z  positiv   negativ
# 406       de  2023-04-11T07:30:49Z  negativ   negativ
# 435       de  2023-04-20T20:54:23Z  positiv   negativ
# 457       de  2023-04-28T14:19:00Z  neutral   negativ
# 497       de  2023-05-14T15:27:30Z  neutral   negativ
# 505       de  2023-05-12T09:44:10Z  negativ   positiv
# 527       de  2023-04-19T06:10:46Z  neutral   negativ
# 530       de  2023-02-09T15:23:04Z  neutral   negativ
# 562       de  2023-05-23T10:52:44Z  negativ   positiv
# 565       de  2023-05-22T08:22:38Z  negativ   negativ
# 576       de  2023-04-23T18:00:31Z  positiv   negativ
# 580       de  2023-04-13T21:20:20Z  neutral   negativ
# 596       de  2023-02-17T17:14:46Z  negativ   negativ
# 604       de  2023-05-21T19:28:06Z  negativ   negativ

# %%
data_con.head()
# Out:
#                                                   data             player  \
# 0    trainer alonso mitgereisten fans monaco glucks...  exequiel palacios
# 72   diesmal andrich entnervt angesprochen standige...  exequiel palacios
# 111  torschutzen sich wirtz jubeln tage wirtz darau...   jeremie frimpong
# 132  hincapie tah bedanken fan unterstutzung tolle ...   jeremie frimpong
# 148  bayerleverkusen vortanzer jubelt uber tor hins...   jeremie frimpong
#
#     language           publishedAt    Label sentiment
# 0         de  2023-02-24T09:33:31Z  positiv   negativ
# 72        de  2023-05-05T18:02:55Z  negativ   negativ
# 111       de  2023-04-02T12:05:20Z  positiv   negativ
# 132       de  2023-04-14T08:16:22Z  positiv   positiv
# 148       de  2023-04-20T21:02:06Z   positv   negativ

# %%
# Calculate the accuracy
accuracy_con = (data_con['sentiment'] == data_con['Label']).mean() * 100

# Print the accuracy
print("Accuracy: {:.2f}%".format(accuracy_con))
# Out:
# Accuracy: 42.86%

# %%
print(data_con['sentiment'].unique())
# Out:
# ['negativ' 'positiv']

# %%
# Assuming you have the true labels in 'Label' column and predicted labels in 'sentiment_label' column of the DataFrame
true_labels = data_con['Label']
predicted_labels = data_con['sentiment']

# Create the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Convert the confusion matrix to a DataFrame for better visualization
labels = np.unique(np.concatenate((true_labels, predicted_labels)))
cm_df = pd.DataFrame(cm, index=labels, columns=labels)

# Display the confusion matrix
print("Confusion Matrix:")
print(cm_df)
# Out:
# Confusion Matrix:
#          negativ  neutal  positiv  positv
# negativ        8       0        2       0
# neutal         1       0        0       0
# positiv        8       0        1       0
# positv         1       0        0       0

# %%
# Assuming you have the true labels in 'Label' column and predicted labels in 'sentiment_label' column of the DataFrame
true_labels = data_con['Label']
predicted_labels = data_con['sentiment']

# Generate the classification report
report = classification_report(true_labels, predicted_labels)

# Display the classification report
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      negativ       0.44      0.80      0.57        10
#       neutal       0.00      0.00      0.00         1
#      positiv       0.33      0.11      0.17         9
#       positv       0.00      0.00      0.00         1
#
#     accuracy                           0.43        21
#    macro avg       0.19      0.23      0.18        21
# weighted avg       0.35      0.43      0.34        21
# C:\Users\joana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\joana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\joana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
