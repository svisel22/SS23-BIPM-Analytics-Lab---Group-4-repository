# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from wordcloud import WordCloud, get_single_color_func

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('modeled_data/word_frequencies.csv')

# %%
df
# Out:
#      Unnamed: 0       Word  Frequency             player language
# 0            40  weltmeist         48  exequiel palacios       de
# 1            16      spiel         46  exequiel palacios       de
# 2            80       adli         39  exequiel palacios       de
# 3            64       sagt         29  exequiel palacios       de
# 4            48      saint         27  exequiel palacios       de
# ..          ...        ...        ...                ...      ...
# 344          57        gol         34     piero hincapié       es
# 345         127    segundo         34     piero hincapié       es
# 346          83       uefa         33     piero hincapié       es
# 347           1      felix         33     piero hincapié       es
# 348         390       roma         33     piero hincapié       es
#
# [349 rows x 5 columns]

# %%
df_de = df[df['language'] == 'de'].copy()
df_en = df[df['language'] == 'en'].copy()
df_es = df[df['language'] == 'es'].copy()

# %%
def fre_graph(df):

        # Assuming you have a DataFrame called 'df' with columns 'words' and 'frequency'
        word_counts = df.set_index('Word')['Frequency'].to_dict()

        wordcloud = WordCloud(width=800, height=400, background_color='black').generate_from_frequencies(word_counts)

        fig, ax = plt.subplots(figsize=(10, 6))
        ax.imshow(wordcloud, interpolation='bilinear')
        ax.axis('off')
        plt.show()
    return
# Out:
#   File <tokenize>:12
#     return
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
fre_graph(df_de)
fre_graph(df_en)
fre_graph(df_es)
