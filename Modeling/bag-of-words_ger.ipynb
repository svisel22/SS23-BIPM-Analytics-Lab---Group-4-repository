# %% [markdown]
# # Stematization

# %%
from gensim.parsing.preprocessing import stem_text
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.corpora import Dictionary
from gensim.models import TfidfModel
sys.path.append('../')
from utils import word_frequency_per_player

# %%
# load data and drop NA's
df = pd.read_csv('https://github.com/svisel22/SS23-BIPM-Analytics-Lab---Group-4-repository/raw/main/Preprocessing/data_clean/de_clean_2.csv')
df_stem = df_stem.dropna(subset=['data'])

# %%
# create column with stemmed data 
df_stem['stemmed_data'] = df_stem['data'].apply(stem_text)

# create a corpus
data_stem = df_stem['stemmed_data'].apply(stem_text)
data = data_stem.tolist()

# %%
len(data)
# Out:
# 622

# %%
# create and fit vectorizer
vectorizerTfid = TfidfVectorizer(max_df=0.95, min_df=0.05, smooth_idf=False)
dataTfid  = vectorizerTfid.fit_transform(data)

# %%
vectorizerTfid.get_feature_names_out()
# Out:
# array(['aber', 'abwehr', 'acht', 'adam', 'adli', 'al', 'all', 'allem',
#        'allerd', 'alonso', 'amiri', 'ander', 'anderen', 'andrich',
#        'angriff', 'anschlusstreff', 'arbeit', 'au', 'auch', 'auf',
#        'ausgleich', 'azmoun', 'bakker', 'ball', 'bank', 'bayer', 'bayern',
#        'bei', 'beid', 'beiden', 'beim', 'belgier', 'bereit', 'berlin',
#        'besser', 'best', 'besten', 'bi', 'bin', 'blieb', 'borussia',
#        'bracht', 'brussel', 'bundesliga', 'champion', 'chanc', 'chancen',
#        'da', 'dabei', 'dafur', 'dagegen', 'damit', 'danach', 'dank',
#        'dann', 'dass', 'dazn', 'de', 'defensiv', 'dem', 'demirbai', 'den',
#        'denn', 'dennoch', 'der', 'dessen', 'deutlich', 'di', 'diabi',
#        'die', 'diesem', 'dieser', 'diesmal', 'doch', 'donnerstag',
#        'dortmund', 'drei', 'druck', 'duell', 'durch', 'edmond', 'ein',
#        'einem', 'einen', 'einer', 'einmal', 'einsatz', 'einzig', 'einzug',
#        'elf', 'elfmet', 'end', 'endspiel', 'erfolgreich', 'erklart',
#        'erreicht', 'erst', 'ersten', 'erzielt', 'etwa', 'euro', 'europa',
#        'europacup', 'fall', 'fan', 'faz', 'fehlt', 'flank', 'frankfurt',
#        'freiburg', 'frimpong', 'fuhrung', 'funf', 'fur', 'fuss',
#        'fussbal', 'gab', 'gaben', 'ganz', 'gast', 'gastgeb', 'gefahrlich',
#        'gegen', 'gegner', 'geht', 'gelb', 'gewonnen', 'gibt', 'gill',
#        'gilloi', 'ging', 'gross', 'gut', 'gute', 'habe', 'haben',
#        'halbfin', 'halbzeit', 'halft', 'hat', 'hatt', 'hatten',
#        'heimspiel', 'hereingab', 'hier', 'hincapi', 'hinspiel', 'hlozek',
#        'hradecki', 'ich', 'ihm', 'ihn', 'ihr', 'immer', 'in', 'ist',
#        'jahr', 'jahren', 'jahrig', 'jedoch', 'jetzt', 'kader', 'kam',
#        'kamen', 'kann', 'kapitan', 'kart', 'kaum', 'kein', 'klar', 'klub',
#        'knapp', 'koln', 'konnen', 'konnt', 'konnten', 'konter', 'kopfbal',
#        'kossoun', 'kurz', 'lang', 'langen', 'latt', 'leagu', 'legt',
#        'leipzig', 'leistung', 'letzt', 'letzten', 'leverkusen', 'liess',
#        'liga', 'link', 'luka', 'machen', 'macht', 'mal', 'man',
#        'mannschaft', 'mehr', 'metern', 'millionen', 'minut', 'minuten',
#        'mit', 'mittelfeld', 'mori', 'mourinho', 'muss', 'mussen', 'musst',
#        'nach', 'nationalspiel', 'neben', 'net', 'nicht', 'niederlag',
#        'niederland', 'noch', 'nun', 'nur', 'oder', 'odilon', 'offen',
#        'offensiv', 'ohn', 'palacio', 'parti', 'pass', 'pau', 'per',
#        'platz', 'posit', 'problem', 'profi', 'punkt', 'recht', 'richtig',
#        'rolf', 'rom', 'roma', 'ruckspiel', 'ruckstand', 'rund', 'sagt',
#        'saint', 'saison', 'sardar', 'schiedsricht', 'schluss', 'schnell',
#        'schon', 'schuss', 'schwer', 'sech', 'sehe', 'sehen', 'sehr',
#        'sei', 'sein', 'seinem', 'seinen', 'seiner', 'seit', 'sekunden',
#        'selbst', 'selten', 'setzt', 'sich', 'sicher', 'sie', 'sieg',
#        'simon', 'sind', 'sogar', 'sommer', 'sonntag', 'sorgt', 'spater',
#        'spiel', 'spielen', 'spieler', 'spielt', 'stand', 'star', 'stark',
#        'starken', 'startelf', 'steht', 'stellt', 'stund', 'sturmer',
#        'stuttgart', 'tah', 'tapsoba', 'team', 'titel', 'tor', 'tore',
#        'torhut', 'torwart', 'traf', 'trafen', 'trainer', 'treffer',
#        'uber', 'uhr', 'un', 'und', 'union', 'unter', 'verdient',
#        'vergangenen', 'verloren', 'versucht', 'verteidig', 'verteidigt',
#        'verzog', 'vfb', 'vfl', 'viel', 'vier', 'viertelfin', 'vom', 'von',
#        'vor', 'wa', 'war', 'ware', 'waren', 'warum', 'wechsel', 'wegen',
#        'weil', 'weit', 'weiter', 'weltmeist', 'wenig', 'wenn', 'werden',
#        'werkself', 'wettbewerb', 'wie', 'wieder', 'will', 'wir', 'wird',
#        'wirtz', 'woch', 'wochen', 'wolfsburg', 'wurd', 'wurden', 'zeigt',
#        'zeit', 'zudem', 'zuletzt', 'zum', 'zumindest', 'zunachst', 'zur',
#        'zuruck', 'zuvor', 'zwar', 'zwei', 'zweimal', 'zweit', 'zweiten'],
#       dtype=object)

# %%
features = vectorizerTfid.get_feature_names_out()
print('Number of Vectorizer Features: ', len(vectorizerTfid.get_feature_names_out()))
# Out:
# Number of Vectorizer Features:  368

# %%
# create a corpus
corpus_gen=[doc.split() for doc in data]

# %%
id2word = Dictionary(corpus_gen)

# %%
# Assume `corpus` is a preprocessed corpus
id2word = Dictionary(corpus_gen)

# Filter out rare and common words
id2word.filter_extremes(no_below=2, no_above=0.99)

# %%
# Display features and their frequencies
df_frequencies = pd.DataFrame(columns=['Word', 'Frequency'])
i = 1
for feature, frequency in id2word.cfs.items():

    # Append a new row to the DataFrame
    df_frequencies.loc[i]= [id2word[feature],frequency]
    i = i+1

# %% [markdown]
# ## Display the Frequency of words

# %%
df_frequencies = df_frequencies.sort_values('Frequency', ascending=False)

# %%
df_frequencies.head(50)
# Out:
#            Word  Frequency
# 17          der       3010
# 40          die       2464
# 50          und       1810
# 4           den       1212
# 55          ein        969
# 31   leverkusen        911
# 75           da        882
# 140         von        874
# 9          nach        869
# 41          auf        813
# 58          fur        781
# 91        bayer        770
# 151         mit        696
# 81        nicht        689
# 13          dem        562
# 184        sich        520
# 172        hatt        467
# 114         war        466
# 43        gegen        462
# 39          ist        459
# 131        aber        449
# 3           vor        445
# 61         auch        438
# 388       diabi        433
# 82           al        431
# 30           au        424
# 107         bei        400
# 2        alonso        387
# 170    frimpong        366
# 337        noch        356
# 34         sein        341
# 12          zum        324
# 153      bakker        319
# 633       wirtz        315
# 96        leagu        309
# 280       einen        299
# 76           de        299
# 1       trainer        288
# 180         hat        285
# 115        doch        284
# 116        dass        284
# 152       einem        269
# 471       einer        263
# 88        spiel        262
# 276         wir        260
# 11          tor        250
# 101         wie        249
# 632         tah        240
# 526        uber        227
# 217       union        223

# %% [markdown]
# ## Display the Frequency of words for each player

# %%
df_de = pd.read_csv('/Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/Preprocessing/data_clean/de_clean_2.csv')
df_en = pd.read_csv('/Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/Preprocessing/data_clean/en_clean_2.csv')
df_es = pd.read_csv('/Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/Preprocessing/data_clean/es_clean_2.csv')

df_freq_de = word_frequency_per_player(df_de, df_de['player'].unique())
df_freq_en = word_frequency_per_player(df_en, df_en['player'].unique())
df_freq_es = word_frequency_per_player(df_es, df_es['player'].unique())

# %%
# Subset for rows in Categoric
def print_player_freq(df_freq):
    for player in df_freq['player'].unique():
        # Delete rows we don't want to see e.g. names etc.
        # Define the strings to be deleted
        strings_to_delete = ['palacio', 'leverkusen', 'bayer', 'exequiel', 'frimpong', 'jeremi', 'tah', 'jonathan', 'bakker', 'mitchel', 'fur', 'moussa', 'diaby', 'mykhaylo', 'piero', 'hincapie', 'nicht', 'diabi']

        # Delete rows containing the specified strings 
        df_freq = df_freq[~df_freq['Word'].isin(strings_to_delete)]


        df_player = df_freq[(df_freq["player"] == player)]
        print('Top Words for ', player , '\n', df_player.head(20), '\n')

# %%
# print frequencies per player for german data
print_player_freq(df_freq_de)
# Out:
# Top Words for  exequiel palacios
#             Word  Frequency             player
# 2        alonso         75  exequiel palacios
# 30        spiel         62  exequiel palacios
# 120        adli         56  exequiel palacios
# 75    weltmeist         48  exequiel palacios
# 1       trainer         48  exequiel palacios
# 97         sagt         45  exequiel palacios
# 223       wirtz         41  exequiel palacios
# 107      bayern         40  exequiel palacios
# 84        saint         36  exequiel palacios
# 21      andrich         34  exequiel palacios
# 35        leagu         32  exequiel palacios
# 63      minuten         32  exequiel palacios
# 121        zwei         31  exequiel palacios
# 127      elfmet         31  exequiel palacios
# 81        union         31  exequiel palacios
# 80         mehr         31  exequiel palacios
# 7    bundesliga         30  exequiel palacios
# 33     hinspiel         29  exequiel palacios
# 252        wurd         29  exequiel palacios
# 34       europa         27  exequiel palacios
#
# Top Words for  jeremie frimpong
#             Word  Frequency            player
# 53       alonso         59  jeremie frimpong
# 168     trainer         58  jeremie frimpong
# 27        leagu         53  jeremie frimpong
# 199       union         47  jeremie frimpong
# 17        wirtz         47  jeremie frimpong
# 42          tor         46  jeremie frimpong
# 169       spiel         40  jeremie frimpong
# 46       bayern         40  jeremie frimpong
# 26       europa         39  jeremie frimpong
# 86         uber         39  jeremie frimpong
# 68   bundesliga         36  jeremie frimpong
# 102        sagt         34  jeremie frimpong
# 18       hlozek         34  jeremie frimpong
# 218        ball         34  jeremie frimpong
# 7      hradecki         32  jeremie frimpong
# 185    hinspiel         31  jeremie frimpong
# 9       andrich         30  jeremie frimpong
# 395         rom         30  jeremie frimpong
# 92         mehr         29  jeremie frimpong
# 126     treffer         27  jeremie frimpong
#
# Top Words for  jonathan tah
#                Word  Frequency        player
# 33          alonso         53  jonathan tah
# 62           leagu         49  jonathan tah
# 107          spiel         42  jonathan tah
# 32         trainer         41  jonathan tah
# 38           wirtz         39  jonathan tah
# 15            uber         38  jonathan tah
# 196         europa         37  jonathan tah
# 50            sagt         35  jonathan tah
# 80           union         34  jonathan tah
# 20             tor         30  jonathan tah
# 77            seit         30  jonathan tah
# 14   nationalspiel         28  jonathan tah
# 45            traf         28  jonathan tah
# 49           immer         24  jonathan tah
# 194          saint         24  jonathan tah
# 19        hradecki         24  jonathan tah
# 16            ball         24  jonathan tah
# 79      bundesliga         23  jonathan tah
# 133           sieg         22  jonathan tah
# 66        werkself         21  jonathan tah
#
# Top Words for  mitchel bakker
#           Word  Frequency          player
# 11     alonso         73  mitchel bakker
# 148    hlozek         64  mitchel bakker
# 112       tor         58  mitchel bakker
# 82      leagu         58  mitchel bakker
# 127     wirtz         57  mitchel bakker
# 114      traf         54  mitchel bakker
# 2     trainer         47  mitchel bakker
# 56    minuten         42  mitchel bakker
# 45      spiel         41  mitchel bakker
# 7        wurd         40  mitchel bakker
# 18     europa         40  mitchel bakker
# 44      minut         37  mitchel bakker
# 150     union         37  mitchel bakker
# 315      ball         36  mitchel bakker
# 126   fuhrung         34  mitchel bakker
# 122      adli         34  mitchel bakker
# 166      adam         31  mitchel bakker
# 81       mehr         30  mitchel bakker
# 157      paus         29  mitchel bakker
# 286  hradecki         26  mitchel bakker
#
# Top Words for  moussa diaby
#             Word  Frequency        player
# 2         wirtz         99  moussa diaby
# 79        leagu         72  moussa diaby
# 3           tor         69  moussa diaby
# 146      alonso         63  moussa diaby
# 94         ball         60  moussa diaby
# 82        union         59  moussa diaby
# 126     trainer         51  moussa diaby
# 64         paus         51  moussa diaby
# 20       hlozek         49  moussa diaby
# 55         uber         48  moussa diaby
# 8        europa         48  moussa diaby
# 56         mehr         48  moussa diaby
# 4          adli         47  moussa diaby
# 131       spiel         42  moussa diaby
# 162        traf         42  moussa diaby
# 242    hinspiel         38  moussa diaby
# 110        team         38  moussa diaby
# 245       saint         37  moussa diaby
# 147       immer         36  moussa diaby
# 40   bundesliga         35  moussa diaby
#
# Top Words for  mykhaylo mudryk
#           Word  Frequency           player
# 1     chelsea         44  mykhaylo mudryk
# 15  millionen         41  mykhaylo mudryk
# 16       euro         35  mykhaylo mudryk
# 8   fernandez         22  mykhaylo mudryk
# 21       mehr         15  mykhaylo mudryk
# 14      leagu         14  mykhaylo mudryk
# 27     winter         13  mykhaylo mudryk
# 2        blue         11  mykhaylo mudryk
# 28     donezk         11  mykhaylo mudryk
# 20       uber         11  mykhaylo mudryk
# 29       enzo         11  mykhaylo mudryk
# 25    spieler         11  mykhaylo mudryk
# 37       joao         11  mykhaylo mudryk
# 38      felix         11  mykhaylo mudryk
# 32     sommer         10  mykhaylo mudryk
# 33       wurd         10  mykhaylo mudryk
# 9    transfer         10  mykhaylo mudryk
# 3       arsen         10  mykhaylo mudryk
# 19      kader          9  mykhaylo mudryk
# 26       klub          8  mykhaylo mudryk
#
# Top Words for  piero hincapie
#                Word  Frequency          player
# 3          hincapi        106  piero hincapie
# 16          alonso         64  piero hincapie
# 31            uber         45  piero hincapie
# 15         trainer         39  piero hincapie
# 53           spiel         35  piero hincapie
# 54           wirtz         32  piero hincapie
# 73           leagu         31  piero hincapie
# 158       demirbai         30  piero hincapie
# 120            tor         27  piero hincapie
# 100         europa         27  piero hincapie
# 90            adli         27  piero hincapie
# 110          minut         24  piero hincapie
# 49   nationalspiel         23  piero hincapie
# 127           ball         23  piero hincapie
# 68        freiburg         20  piero hincapie
# 133           kurz         19  piero hincapie
# 37           immer         19  piero hincapie
# 180      ausgleich         18  piero hincapie
# 45        versucht         17  piero hincapie
# 220       mourinho         17  piero hincapie

# %%
# print frequencies per player for english data
print_player_freq(df_freq_en)
# Out:
# Top Words for  exequiel palacios
#             Word Frequency             player
# 1          goal       218  exequiel palacios
# 69       bayern       195  exequiel palacios
# 38          win       172  exequiel palacios
# 54        point       156  exequiel palacios
# 30        minut       155  exequiel palacios
# 20        score       153  exequiel palacios
# 162       union       152  exequiel palacios
# 5         leagu       124  exequiel palacios
# 142        lead       112  exequiel palacios
# 19         time       112  exequiel palacios
# 198   frankfurt       106  exequiel palacios
# 95       second       105  exequiel palacios
# 189    dortmund        95  exequiel palacios
# 400     khedira        94  exequiel palacios
# 18         ball        90  exequiel palacios
# 133        home        88  exequiel palacios
# 63   bundesliga        86  exequiel palacios
# 96         half        81  exequiel palacios
# 122     penalti        77  exequiel palacios
# 91         awai        73  exequiel palacios
#
# Top Words for  jeremie frimpong
#           Word Frequency            player
# 177     match      1310  jeremie frimpong
# 2        unit       864  jeremie frimpong
# 182     leagu       741  jeremie frimpong
# 217    player       568  jeremie frimpong
# 494      goal       564  jeremie frimpong
# 1    manchest       519  jeremie frimpong
# 398     minut       511  jeremie frimpong
# 24        new       503  jeremie frimpong
# 68     season       479  jeremie frimpong
# 542     score       460  jeremie frimpong
# 126       xa-       455  jeremie frimpong
# 180      time       414  jeremie frimpong
# 181   premier       381  jeremie frimpong
# 295      year       360  jeremie frimpong
# 16       sign       342  jeremie frimpong
# 770     union       336  jeremie frimpong
# 218    summer       333  jeremie frimpong
# 248      club       325  jeremie frimpong
# 25        old       324  jeremie frimpong
# 877     watch       323  jeremie frimpong
#
# Top Words for  jonathan tah
#         Word Frequency        player
# 5      year       746  jonathan tah
# 9    includ       417  jonathan tah
# 22   follow       392  jonathan tah
# 14     time       364  jonathan tah
# 23   member       226  jonathan tah
# 17     work       213  jonathan tah
# 19     citi       200  jonathan tah
# 12   second       189  jonathan tah
# 4       end       143  jonathan tah
# 1       new       126  jonathan tah
# 10     come       120  jonathan tah
# 26    world       116  jonathan tah
# 16   depart       113  jonathan tah
# 27  continu       110  jonathan tah
# 30   finish        70  jonathan tah
# 8      mean        65  jonathan tah
# 6    result        64  jonathan tah
# 2      like        61  jonathan tah
# 3      went        58  jonathan tah
# 28     week        57  jonathan tah
#
# Top Words for  mitchel bakker
#         Word Frequency          player
# 33    minut       337  mitchel bakker
# 29    score       250  mitchel bakker
# 57   aggreg       185  mitchel bakker
# 21     time       172  mitchel bakker
# 35   second       156  mitchel bakker
# 19    final       124  mitchel bakker
# 22     team       122  mitchel bakker
# 54    union       113  mitchel bakker
# 24    sport       113  mitchel bakker
# 63     roma       108  mitchel bakker
# 65     said        99  mitchel bakker
# 10    leagu        92  mitchel bakker
# 58      leg        85  mitchel bakker
# 23    coach        80  mitchel bakker
# 50      win        80  mitchel bakker
# 30  penalti        79  mitchel bakker
# 52   europa        79  mitchel bakker
# 34    twice        72  mitchel bakker
# 46     ball        70  mitchel bakker
# 48     adam        70  mitchel bakker
#
# Top Words for  moussa diaby
#           Word Frequency        player
# 54      match      1310  moussa diaby
# 218     leagu       822  moussa diaby
# 46      minut       733  moussa diaby
# 39        win       671  moussa diaby
# 134    player       664  moussa diaby
# 931   network       662  moussa diaby
# 43      score       642  moussa diaby
# 658     arsen       617  moussa diaby
# 68       goal       600  moussa diaby
# 35       time       535  moussa diaby
# 262    season       520  moussa diaby
# 192      team       493  moussa diaby
# 62     second       473  moussa diaby
# 27       game       423  moussa diaby
# 356      plai       414  moussa diaby
# 2        citi       381  moussa diaby
# 133       new       361  moussa diaby
# 502     watch       354  moussa diaby
# 363  midfield       352  moussa diaby
# 781   premier       348  moussa diaby
#
# Top Words for  mykhaylo mudryk
#              Word Frequency           player
# 508        recap      8064  mykhaylo mudryk
# 230        match      7376  mykhaylo mudryk
# 507       replai      7274  mykhaylo mudryk
# 168          usa      4023  mykhaylo mudryk
# 386      network      3949  mykhaylo mudryk
# 538          xa-      2544  mykhaylo mudryk
# 7         player      2400  mykhaylo mudryk
# 10         watch      1833  mykhaylo mudryk
# 1        premier      1775  mykhaylo mudryk
# 63       chelsea      1600  mykhaylo mudryk
# 92          citi      1520  mykhaylo mudryk
# 509         rate      1467  mykhaylo mudryk
# 210          man      1262  mykhaylo mudryk
# 20         arsen      1221  mykhaylo mudryk
# 9         season      1158  mykhaylo mudryk
# 132          ham      1097  mykhaylo mudryk
# 40         villa      1061  mykhaylo mudryk
# 79         palac      1053  mykhaylo mudryk
# 93     liverpool      1009  mykhaylo mudryk
# 44   bournemouth      1005  mykhaylo mudryk
#
# Top Words for  piero hincapie
#            Word Frequency          player
# 91        club       102  piero hincapie
# 76    transfer        86  piero hincapie
# 19        sign        80  piero hincapie
# 6     midfield        77  piero hincapie
# 11        year        77  piero hincapie
# 12         old        53  piero hincapie
# 147     season        51  piero hincapie
# 56        time        50  piero hincapie
# 79        game        47  piero hincapie
# 21   tottenham        47  piero hincapie
# 67      defend        45  piero hincapie
# 71         new        45  piero hincapie
# 175       valu        45  piero hincapie
# 28        unit        44  piero hincapie
# 97      player        41  piero hincapie
# 94    manchest        41  piero hincapie
# 44       leagu        40  piero hincapie
# 24        loan        39  piero hincapie
# 33        left        36  piero hincapie
# 15      summer        35  piero hincapie

# %%
# print frequencies per player for spanish data
print_player_freq(df_freq_es)
# Out:
# Top Words for  Exequiel Palacios
#            Word Frequency             player
# 58    martínez       123  Exequiel Palacios
# 70      nicolá        79  Exequiel Palacios
# 109         el        70  Exequiel Palacios
# 125     lionel        65  Exequiel Palacios
# 107         no        63  Exequiel Palacios
# 51       ángel        58  Exequiel Palacios
# 67     montiel        52  Exequiel Palacios
# 66     gonzalo        50  Exequiel Palacios
# 88   fernández        49  Exequiel Palacios
# 69    pezzella        48  Exequiel Palacios
# 86       pared        48  Exequiel Palacios
# 103     dybala        48  Exequiel Palacios
# 50       messi        48  Exequiel Palacios
# 79       marco        48  Exequiel Palacios
# 102      paulo        47  Exequiel Palacios
# 100    lautaro        47  Exequiel Palacios
# 89       guido        47  Exequiel Palacios
# 68      germán        47  Exequiel Palacios
# 80       acuña        47  Exequiel Palacios
# 85     leandro        47  Exequiel Palacios
#
# Top Words for  Jeremie Frimpong
#          Word Frequency            player
# 5         el        35  Jeremie Frimpong
# 22        no        16  Jeremie Frimpong
# 15   mercado        13  Jeremie Frimpong
# 29    alonso        12  Jeremie Frimpong
# 26        en        12  Jeremie Frimpong
# 17    fútbol        12  Jeremie Frimpong
# 14    minuto        12  Jeremie Frimpong
# 28      xabi        11  Jeremie Frimpong
# 16    fichaj        11  Jeremie Frimpong
# 10     later        11  Jeremie Frimpong
# 18   directo        10  Jeremie Frimpong
# 25    bayern         8  Jeremie Frimpong
# 9      final         8  Jeremie Frimpong
# 30       gol         8  Jeremie Frimpong
# 3     europa         8  Jeremie Frimpong
# 27    equipo         7  Jeremie Frimpong
# 31         a         7  Jeremie Frimpong
# 21       tra         7  Jeremie Frimpong
# 23  marcador         6  Jeremie Frimpong
# 7    partido         6  Jeremie Frimpong
#
# Top Words for  Mitchel Bakker
#          Word Frequency          player
# 12        el        17  Mitchel Bakker
# 3     equipo         9  Mitchel Bakker
# 11        en         9  Mitchel Bakker
# 2   hincapié         8  Mitchel Bakker
# 6    partido         7  Mitchel Bakker
# 7     minuto         7  Mitchel Bakker
# 8        tra         5  Mitchel Bakker
#
# Top Words for  Moussa Diaby
#          Word Frequency        player
# 13        el        37  Moussa Diaby
# 2    partido        19  Moussa Diaby
# 24    minuto        19  Moussa Diaby
# 43        no        16  Moussa Diaby
# 10     wirtz        16  Moussa Diaby
# 35    alonso        14  Moussa Diaby
# 26    equipo        14  Moussa Diaby
# 9    florian        14  Moussa Diaby
# 1         en        13  Moussa Diaby
# 34      xabi        13  Moussa Diaby
# 11    europa        12  Moussa Diaby
# 39       tra        12  Moussa Diaby
# 25         a        12  Moussa Diaby
# 32   primera        12  Moussa Diaby
# 18     final        11  Moussa Diaby
# 55      área        11  Moussa Diaby
# 48      adli        11  Moussa Diaby
# 12     leagu        10  Moussa Diaby
# 15  hincapié        10  Moussa Diaby
# 5        gol        10  Moussa Diaby
#
# Top Words for  Mykhaylo Mudryk
#           Word Frequency           player
# 21     millon        46  Mykhaylo Mudryk
# 8      fichaj        28  Mykhaylo Mudryk
# 11    chelsea        27  Mykhaylo Mudryk
# 16         no        22  Mykhaylo Mudryk
# 4     mercado        22  Mykhaylo Mudryk
# 22       euro        19  Mykhaylo Mudryk
# 38      félix        17  Mykhaylo Mudryk
# 27  fernández        16  Mykhaylo Mudryk
# 26       enzo        15  Mykhaylo Mudryk
# 31     maduek        14  Mykhaylo Mudryk
# 39         el        14  Mykhaylo Mudryk
# 36     fofana        14  Mykhaylo Mudryk
# 37       joao        14  Mykhaylo Mudryk
# 3      equipo        13  Mykhaylo Mudryk
# 29  badiashil        13  Mykhaylo Mudryk
# 6   temporada        12  Mykhaylo Mudryk
# 55       blue        12  Mykhaylo Mudryk
# 30       noni        12  Mykhaylo Mudryk
# 9      fútbol        12  Mykhaylo Mudryk
# 53  ucraniano        11  Mykhaylo Mudryk
#
# Top Words for  Piero Hincapié
#              Word Frequency          player
# 8             el       148  Piero Hincapié
# 6    ecuatoriano        71  Piero Hincapié
# 19         leagu        62  Piero Hincapié
# 46            en        61  Piero Hincapié
# 3         europa        60  Piero Hincapié
# 20       partido        54  Piero Hincapié
# 56            no        53  Piero Hincapié
# 121       equipo        47  Piero Hincapié
# 76            la        46  Piero Hincapié
# 75       ecuador        41  Piero Hincapié
# 1          félix        37  Piero Hincapié
# 42        minuto        34  Piero Hincapié
# 99         moisé        34  Piero Hincapié
# 171         uefa        33  Piero Hincapié
# 197        final        33  Piero Hincapié
# 4        jugador        32  Piero Hincapié
# 143      defensa        31  Piero Hincapié
# 184        rival        30  Piero Hincapié
# 67            do        29  Piero Hincapié
# 125       primer        27  Piero Hincapié

# %% [markdown]
# ## For sentiment analyses To proceed with less datapoints in some months build Confidents intervall

# %% [markdown]
# # Other

# %%
# load data and drop NA's
df = pd.read_csv('https://github.com/svisel22/SS23-BIPM-Analytics-Lab---Group-4-repository/raw/main/Preprocessing/data_clean/de_clean_2.csv')
df = df.dropna(subset=['data'])

# create two copies 
df_stem = df.copy()
df_bert = df.copy()

# create stemmed data
df_stem['data'] = df_stem['data'].apply(stem_text)

# create a corpus
data_stemmed = df_stem['data'].tolist()


# create bert data
data_bert = df_bert['data'].tolist()
data_bert = [str(item) for item in data_bert]
data_bert = ['[CLS]' + s + '[SEP]' for s in data_bert]

#Tokenize with bert
# define bert tokenizer
bert_uncased = BertTokenizer.from_pretrained('bert-base-uncased')

# tokenize the data
tokenized_texts = [bert_uncased.tokenize(text) for text in data_bert]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 23
#      19 data_bert = ['[CLS]' + s + '[SEP]' for s in data_bert]
#      21 #Tokenize with bert
#      22 # define bert tokenizer
# ---> 23 bert_uncased = BertTokenizer.from_pretrained('bert-base-uncased')
#      25 # tokenize the data
#      26 tokenized_texts = [bert_uncased.tokenize(text) for text in data_bert]
#
# NameError: name 'BertTokenizer' is not defined
