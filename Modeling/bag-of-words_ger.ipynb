# %% [markdown]
# # Stematization

# %%
from gensim.parsing.preprocessing import stem_text
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.corpora import Dictionary
from gensim.models import TfidfModel
sys.path.append('../')
from utils import word_frequency_per_player

# %%
# load data and drop NA's
df_stem = pd.read_csv('/Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/Preprocessing/data_clean/de_clean_2.csv')
df_stem = df_stem.dropna(subset=['data'])

# %%
# create column with stemmed data 
df_stem['stemmed_data'] = df_stem['data'].apply(stem_text)

# create a corpus
data_stem = df_stem['stemmed_data'].apply(stem_text)
data = data_stem.tolist()

# %%
len(data)
# Out:
# 622

# %%
# create and fit vectorizer
vectorizerTfid = TfidfVectorizer(max_df=0.95, min_df=0.05, smooth_idf=False)
dataTfid  = vectorizerTfid.fit_transform(data)

# %%
vectorizerTfid.get_feature_names_out()
# Out:
# array(['abwehr', 'acht', 'adam', 'adli', 'allerd', 'alonso', 'amin',
#        'amiri', 'andrich', 'angriff', 'anschlusstreff', 'arbeit',
#        'ausgleich', 'azmoun', 'bakker', 'ball', 'bank', 'bayer', 'bayern',
#        'beid', 'beiden', 'beim', 'belgier', 'bereit', 'berlin', 'besser',
#        'best', 'besten', 'blieb', 'borussia', 'bracht', 'brussel',
#        'bundesliga', 'champion', 'chanc', 'chancen', 'dabei', 'dafur',
#        'dagegen', 'danach', 'dank', 'dazn', 'defensiv', 'demirbai',
#        'dennoch', 'deutlich', 'diabi', 'diesmal', 'donnerstag',
#        'dortmund', 'drei', 'druck', 'duell', 'edmond', 'einsatz',
#        'einzig', 'einzug', 'elf', 'elfmet', 'end', 'endspiel',
#        'erfolgreich', 'erklart', 'erreicht', 'erst', 'ersten', 'erzielt',
#        'euro', 'europa', 'europacup', 'exequiel', 'fall', 'fan', 'faz',
#        'fehlt', 'flank', 'florian', 'frankfurt', 'freiburg', 'frimpong',
#        'fuhrung', 'funf', 'fur', 'fuss', 'fussbal', 'gab', 'gaben',
#        'ganz', 'gast', 'gastgeb', 'gefahrlich', 'gegner', 'geht', 'gelb',
#        'gewonnen', 'gibt', 'gill', 'gilloi', 'ging', 'gross', 'gut',
#        'gute', 'halbfin', 'halbzeit', 'halft', 'heimspiel', 'hereingab',
#        'hincapi', 'hinspiel', 'hlozek', 'hradecki', 'immer', 'jahr',
#        'jahren', 'jahrig', 'jedoch', 'jeremi', 'jonathan', 'kader', 'kam',
#        'kamen', 'kapitan', 'kart', 'kaum', 'kerem', 'klar', 'klub',
#        'knapp', 'koln', 'konnen', 'konnt', 'konnten', 'konter', 'kopfbal',
#        'kossoun', 'kurz', 'lang', 'langen', 'latt', 'leagu', 'legt',
#        'leipzig', 'leistung', 'letzt', 'letzten', 'leverkusen', 'liess',
#        'liga', 'link', 'luka', 'macht', 'mal', 'mannschaft', 'mehr',
#        'metern', 'millionen', 'minut', 'minuten', 'mitchel', 'mittelfeld',
#        'mori', 'mourinho', 'moussa', 'mussen', 'nadiem', 'nationalspiel',
#        'neben', 'net', 'nicht', 'niederlag', 'niederland', 'odilon',
#        'offen', 'offensiv', 'palacio', 'parti', 'pass', 'pau', 'per',
#        'piero', 'platz', 'posit', 'problem', 'profi', 'punkt', 'recht',
#        'richtig', 'robert', 'rolf', 'rom', 'roma', 'ruckspiel',
#        'ruckstand', 'rund', 'sagt', 'saint', 'saison', 'sardar',
#        'schiedsricht', 'schluss', 'schnell', 'schon', 'schuss', 'schwer',
#        'sech', 'sehe', 'sehen', 'sei', 'seit', 'sekunden', 'selten',
#        'setzt', 'sicher', 'sieg', 'simon', 'sogar', 'sommer', 'sonntag',
#        'sorgt', 'spater', 'spiel', 'spielen', 'spieler', 'spielt',
#        'stand', 'star', 'stark', 'starken', 'startelf', 'steht', 'stellt',
#        'stund', 'sturmer', 'stuttgart', 'tah', 'tapsoba', 'team', 'titel',
#        'tor', 'tore', 'torhut', 'torwart', 'traf', 'trafen', 'trainer',
#        'treffer', 'uber', 'uhr', 'union', 'verdient', 'vergangenen',
#        'verloren', 'versucht', 'verteidig', 'verteidigt', 'verzog', 'vfb',
#        'vfl', 'viel', 'vier', 'viertelfin', 'ware', 'warum', 'wechsel',
#        'wegen', 'weit', 'weiter', 'weltmeist', 'wenig', 'werkself',
#        'wettbewerb', 'wirtz', 'woch', 'wochen', 'wolfsburg', 'wurd',
#        'wurden', 'xabi', 'zeigt', 'zeit', 'zudem', 'zuletzt', 'zumindest',
#        'zunachst', 'zuruck', 'zuvor', 'zwei', 'zweimal', 'zweit',
#        'zweiten'], dtype=object)

# %%
features = vectorizerTfid.get_feature_names_out()
print('Number of Vectorizer Features: ', len(vectorizerTfid.get_feature_names_out()))
# Out:
# Number of Vectorizer Features:  290

# %% [markdown]
# ## Back of words with gensim

# %%
# create a corpus
corpus_gen=[doc.split() for doc in data]

# %%
id2word = Dictionary(corpus_gen)

# %%
# Assume `corpus` is a preprocessed corpus
id2word = Dictionary(corpus_gen)

# Filter out rare and common words
id2word.filter_extremes(no_below=2, no_above=0.99)

# %%
# Display features and their frequencies
df_frequencies = pd.DataFrame(columns=['Word', 'Frequency'])
i = 1
for feature, frequency in id2word.cfs.items():

    # Append a new row to the DataFrame
    df_frequencies.loc[i]= [id2word[feature],frequency]
    i = i+1

# %% [markdown]
# ## Display the Frequency of words

# %%
df_frequencies = df_frequencies.sort_values('Frequency', ascending=False)

# %%
df_frequencies.head(50)
# Out:
#            Word  Frequency
# 24   leverkusen        911
# 45          fur        781
# 73        bayer        770
# 64        nicht        689
# 329       diabi        432
# 3        alonso        376
# 134    frimpong        364
# 118      bakker        319
# 78        leagu        309
# 566       wirtz        308
# 1       trainer        288
# 70        spiel        262
# 2          xabi        252
# 9           tor        250
# 565         tah        241
# 461        uber        227
# 328      moussa        225
# 175       union        223
# 77       europa        219
# 133      jeremi        215
# 8       palacio        213
# 16         beim        205
# 303        adli        202
# 337        ball        197
# 301      hlozek        194
# 28        schon        188
# 169        mehr        179
# 32         seit        178
# 611        traf        173
# 918     florian        168
# 232        sagt        166
# 564     hincapi        161
# 114     halbfin        157
# 117     mitchel        156
# 691        wurd        156
# 13   bundesliga        156
# 139     minuten        153
# 76     hinspiel        150
# 21          pau        149
# 199       minut        147
# 185       saint        145
# 268        erst        139
# 770       immer        138
# 996    jonathan        137
# 265      bayern        135
# 7      exequiel        133
# 553    hradecki        132
# 94       ersten        123
# 305        zwei        122
# 92     werkself        121

# %% [markdown]
# ## Display the Frequency of words for each player

# %%
df_de = pd.read_csv('/Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/Preprocessing/data_clean/de_clean_2.csv')
df_en = pd.read_csv('/Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/Preprocessing/data_clean/en_clean_2.csv')
df_es = pd.read_csv('/Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/Preprocessing/data_clean/es_clean_2.csv')

df_freq_de = word_frequency_per_player(df_de, df_de['player'].unique())
df_freq_en = word_frequency_per_player(df_en, df_en['player'].unique())
df_freq_es = word_frequency_per_player(df_es, df_es['player'].unique())

# %%
# Subset for rows in Categoric
def print_player_freq(df_freq):
    for player in df_freq['player'].unique():
        # Delete rows we don't want to see e.g. names etc.
        # Define the strings to be deleted
        strings_to_delete = ['palacio', 'leverkusen', 'bayer', 'exequiel', 'frimpong', 'jeremi', 'tah', 'jonathan', 'bakker', 'mitchel', 'fur', 'moussa', 'diaby', 'mykhaylo', 'piero', 'hincapie', 'nicht', 'diabi']

        # Delete rows containing the specified strings 
        df_freq = df_freq[~df_freq['Word'].isin(strings_to_delete)]


        df_player = df_freq[(df_freq["player"] == player)]
        print('Top Words for ', player , '\n', df_player.head(20), '\n')

# %%
# print frequencies per player for german data
print_player_freq(df_freq_de)
# Out:
# Top Words for  exequiel palacios
#             Word  Frequency             player
# 3        alonso         70  exequiel palacios
# 37        spiel         62  exequiel palacios
# 134        adli         54  exequiel palacios
# 2          xabi         51  exequiel palacios
# 1       trainer         48  exequiel palacios
# 85    weltmeist         48  exequiel palacios
# 108        sagt         45  exequiel palacios
# 238       wirtz         41  exequiel palacios
# 119      bayern         40  exequiel palacios
# 94        saint         36  exequiel palacios
# 12         beim         36  exequiel palacios
# 28      andrich         34  exequiel palacios
# 42        leagu         32  exequiel palacios
# 73      minuten         32  exequiel palacios
# 133        amin         31  exequiel palacios
# 90         mehr         31  exequiel palacios
# 135        zwei         31  exequiel palacios
# 141      elfmet         31  exequiel palacios
# 91        union         31  exequiel palacios
# 9    bundesliga         30  exequiel palacios
#
# Top Words for  jeremie frimpong
#             Word  Frequency            player
# 57       alonso         58  jeremie frimpong
# 174     trainer         58  jeremie frimpong
# 27        leagu         53  jeremie frimpong
# 17        wirtz         47  jeremie frimpong
# 206       union         47  jeremie frimpong
# 44          tor         46  jeremie frimpong
# 265        xabi         41  jeremie frimpong
# 229       schon         40  jeremie frimpong
# 48       bayern         40  jeremie frimpong
# 175       spiel         40  jeremie frimpong
# 91         uber         39  jeremie frimpong
# 26       europa         39  jeremie frimpong
# 127        beim         37  jeremie frimpong
# 73   bundesliga         36  jeremie frimpong
# 166        seit         34  jeremie frimpong
# 18       hlozek         34  jeremie frimpong
# 226        ball         34  jeremie frimpong
# 107        sagt         34  jeremie frimpong
# 7      hradecki         32  jeremie frimpong
# 192    hinspiel         31  jeremie frimpong
#
# Top Words for  jonathan tah
#                Word  Frequency        player
# 42          alonso         53  jonathan tah
# 74           leagu         49  jonathan tah
# 120          spiel         42  jonathan tah
# 40         trainer         41  jonathan tah
# 16            uber         38  jonathan tah
# 211         europa         37  jonathan tah
# 48           wirtz         36  jonathan tah
# 61            sagt         35  jonathan tah
# 92           union         34  jonathan tah
# 142           beim         32  jonathan tah
# 41            xabi         32  jonathan tah
# 89            seit         31  jonathan tah
# 21             tor         30  jonathan tah
# 47         florian         29  jonathan tah
# 55            traf         28  jonathan tah
# 15   nationalspiel         28  jonathan tah
# 167          schon         25  jonathan tah
# 20        hradecki         24  jonathan tah
# 209          saint         24  jonathan tah
# 60           immer         24  jonathan tah
#
# Top Words for  mitchel bakker
#          Word  Frequency          player
# 13    alonso         71  mitchel bakker
# 157   hlozek         64  mitchel bakker
# 87     leagu         58  mitchel bakker
# 117      tor         58  mitchel bakker
# 119     traf         54  mitchel bakker
# 135    wirtz         54  mitchel bakker
# 2    trainer         47  mitchel bakker
# 44      xabi         43  mitchel bakker
# 60   minuten         42  mitchel bakker
# 49     spiel         41  mitchel bakker
# 8       wurd         40  mitchel bakker
# 20    europa         40  mitchel bakker
# 159    union         37  mitchel bakker
# 48     minut         37  mitchel bakker
# 331     ball         36  mitchel bakker
# 134  fuhrung         34  mitchel bakker
# 130     adli         34  mitchel bakker
# 6      schon         33  mitchel bakker
# 45      beim         32  mitchel bakker
# 223     seit         31  mitchel bakker
#
# Top Words for  moussa diaby
#          Word  Frequency        player
# 4      wirtz         98  moussa diaby
# 86     leagu         72  moussa diaby
# 5        tor         69  moussa diaby
# 154   alonso         62  moussa diaby
# 101     ball         60  moussa diaby
# 89     union         59  moussa diaby
# 71      paus         51  moussa diaby
# 133  trainer         51  moussa diaby
# 24    hlozek         49  moussa diaby
# 12    europa         48  moussa diaby
# 62      mehr         48  moussa diaby
# 61      uber         48  moussa diaby
# 7       adli         47  moussa diaby
# 3    florian         47  moussa diaby
# 170     traf         42  moussa diaby
# 138    spiel         42  moussa diaby
# 70     schon         41  moussa diaby
# 153     xabi         41  moussa diaby
# 79      seit         39  moussa diaby
# 117     team         38  moussa diaby
#
# Top Words for  mykhaylo mudryk
#           Word  Frequency           player
# 1     chelsea         44  mykhaylo mudryk
# 16  millionen         41  mykhaylo mudryk
# 17       euro         35  mykhaylo mudryk
# 9   fernandez         22  mykhaylo mudryk
# 22       mehr         15  mykhaylo mudryk
# 15      leagu         14  mykhaylo mudryk
# 28     winter         13  mykhaylo mudryk
# 2        blue         11  mykhaylo mudryk
# 29     donezk         11  mykhaylo mudryk
# 21       uber         11  mykhaylo mudryk
# 30       enzo         11  mykhaylo mudryk
# 26    spieler         11  mykhaylo mudryk
# 38       joao         11  mykhaylo mudryk
# 39      felix         11  mykhaylo mudryk
# 33     sommer         10  mykhaylo mudryk
# 34       wurd         10  mykhaylo mudryk
# 10   transfer         10  mykhaylo mudryk
# 4       arsen         10  mykhaylo mudryk
# 20      kader          9  mykhaylo mudryk
# 27       klub          8  mykhaylo mudryk
#
# Top Words for  piero hincapie
#                Word  Frequency          player
# 5          hincapi        102  piero hincapie
# 20          alonso         62  piero hincapie
# 39            uber         45  piero hincapie
# 19            xabi         44  piero hincapie
# 18         trainer         39  piero hincapie
# 62           spiel         35  piero hincapie
# 64           wirtz         32  piero hincapie
# 84           leagu         31  piero hincapie
# 173       demirbai         30  piero hincapie
# 25            beim         29  piero hincapie
# 102           adli         27  piero hincapie
# 134            tor         27  piero hincapie
# 112         europa         27  piero hincapie
# 63         florian         24  piero hincapie
# 123          minut         24  piero hincapie
# 141           ball         23  piero hincapie
# 58   nationalspiel         23  piero hincapie
# 6            schon         22  piero hincapie
# 7             seit         21  piero hincapie
# 78        freiburg         20  piero hincapie

# %%
# print frequencies per player for english data
print_player_freq(df_freq_en)
# Out:
# Top Words for  exequiel palacios
#             Word Frequency             player
# 1          goal       218  exequiel palacios
# 69       bayern       195  exequiel palacios
# 38          win       172  exequiel palacios
# 54        point       156  exequiel palacios
# 30        minut       155  exequiel palacios
# 20        score       153  exequiel palacios
# 162       union       152  exequiel palacios
# 5         leagu       124  exequiel palacios
# 142        lead       112  exequiel palacios
# 19         time       112  exequiel palacios
# 198   frankfurt       106  exequiel palacios
# 95       second       105  exequiel palacios
# 189    dortmund        95  exequiel palacios
# 400     khedira        94  exequiel palacios
# 18         ball        90  exequiel palacios
# 133        home        88  exequiel palacios
# 63   bundesliga        86  exequiel palacios
# 96         half        81  exequiel palacios
# 122     penalti        77  exequiel palacios
# 91         awai        73  exequiel palacios
#
# Top Words for  jeremie frimpong
#           Word Frequency            player
# 177     match      1310  jeremie frimpong
# 2        unit       864  jeremie frimpong
# 182     leagu       741  jeremie frimpong
# 217    player       568  jeremie frimpong
# 494      goal       564  jeremie frimpong
# 1    manchest       519  jeremie frimpong
# 398     minut       511  jeremie frimpong
# 24        new       503  jeremie frimpong
# 68     season       479  jeremie frimpong
# 542     score       460  jeremie frimpong
# 126       xa-       455  jeremie frimpong
# 180      time       414  jeremie frimpong
# 181   premier       381  jeremie frimpong
# 295      year       360  jeremie frimpong
# 16       sign       342  jeremie frimpong
# 770     union       336  jeremie frimpong
# 218    summer       333  jeremie frimpong
# 248      club       325  jeremie frimpong
# 25        old       324  jeremie frimpong
# 877     watch       323  jeremie frimpong
#
# Top Words for  jonathan tah
#         Word Frequency        player
# 5      year       746  jonathan tah
# 9    includ       417  jonathan tah
# 22   follow       392  jonathan tah
# 14     time       364  jonathan tah
# 23   member       226  jonathan tah
# 17     work       213  jonathan tah
# 19     citi       200  jonathan tah
# 12   second       189  jonathan tah
# 4       end       143  jonathan tah
# 1       new       126  jonathan tah
# 10     come       120  jonathan tah
# 26    world       116  jonathan tah
# 16   depart       113  jonathan tah
# 27  continu       110  jonathan tah
# 30   finish        70  jonathan tah
# 8      mean        65  jonathan tah
# 6    result        64  jonathan tah
# 2      like        61  jonathan tah
# 3      went        58  jonathan tah
# 28     week        57  jonathan tah
#
# Top Words for  mitchel bakker
#         Word Frequency          player
# 33    minut       337  mitchel bakker
# 29    score       250  mitchel bakker
# 57   aggreg       185  mitchel bakker
# 21     time       172  mitchel bakker
# 35   second       156  mitchel bakker
# 19    final       124  mitchel bakker
# 22     team       122  mitchel bakker
# 54    union       113  mitchel bakker
# 24    sport       113  mitchel bakker
# 63     roma       108  mitchel bakker
# 65     said        99  mitchel bakker
# 10    leagu        92  mitchel bakker
# 58      leg        85  mitchel bakker
# 23    coach        80  mitchel bakker
# 50      win        80  mitchel bakker
# 30  penalti        79  mitchel bakker
# 52   europa        79  mitchel bakker
# 34    twice        72  mitchel bakker
# 46     ball        70  mitchel bakker
# 48     adam        70  mitchel bakker
#
# Top Words for  moussa diaby
#           Word Frequency        player
# 54      match      1310  moussa diaby
# 218     leagu       822  moussa diaby
# 46      minut       733  moussa diaby
# 39        win       671  moussa diaby
# 134    player       664  moussa diaby
# 931   network       662  moussa diaby
# 43      score       642  moussa diaby
# 658     arsen       617  moussa diaby
# 68       goal       600  moussa diaby
# 35       time       535  moussa diaby
# 262    season       520  moussa diaby
# 192      team       493  moussa diaby
# 62     second       473  moussa diaby
# 27       game       423  moussa diaby
# 356      plai       414  moussa diaby
# 2        citi       381  moussa diaby
# 133       new       361  moussa diaby
# 502     watch       354  moussa diaby
# 363  midfield       352  moussa diaby
# 781   premier       348  moussa diaby
#
# Top Words for  mykhaylo mudryk
#              Word Frequency           player
# 508        recap      8064  mykhaylo mudryk
# 230        match      7376  mykhaylo mudryk
# 507       replai      7274  mykhaylo mudryk
# 168          usa      4023  mykhaylo mudryk
# 386      network      3949  mykhaylo mudryk
# 538          xa-      2544  mykhaylo mudryk
# 7         player      2400  mykhaylo mudryk
# 10         watch      1833  mykhaylo mudryk
# 1        premier      1775  mykhaylo mudryk
# 63       chelsea      1600  mykhaylo mudryk
# 92          citi      1520  mykhaylo mudryk
# 509         rate      1467  mykhaylo mudryk
# 210          man      1262  mykhaylo mudryk
# 20         arsen      1221  mykhaylo mudryk
# 9         season      1158  mykhaylo mudryk
# 132          ham      1097  mykhaylo mudryk
# 40         villa      1061  mykhaylo mudryk
# 79         palac      1053  mykhaylo mudryk
# 93     liverpool      1009  mykhaylo mudryk
# 44   bournemouth      1005  mykhaylo mudryk
#
# Top Words for  piero hincapie
#            Word Frequency          player
# 91        club       102  piero hincapie
# 76    transfer        86  piero hincapie
# 19        sign        80  piero hincapie
# 6     midfield        77  piero hincapie
# 11        year        77  piero hincapie
# 12         old        53  piero hincapie
# 147     season        51  piero hincapie
# 56        time        50  piero hincapie
# 79        game        47  piero hincapie
# 21   tottenham        47  piero hincapie
# 67      defend        45  piero hincapie
# 71         new        45  piero hincapie
# 175       valu        45  piero hincapie
# 28        unit        44  piero hincapie
# 97      player        41  piero hincapie
# 94    manchest        41  piero hincapie
# 44       leagu        40  piero hincapie
# 24        loan        39  piero hincapie
# 33        left        36  piero hincapie
# 15      summer        35  piero hincapie

# %%
# print frequencies per player for spanish data
print_player_freq(df_freq_es)
# Out:
# Top Words for  Exequiel Palacios
#            Word Frequency             player
# 47          el       393  Exequiel Palacios
# 33          no       357  Exequiel Palacios
# 80          la       220  Exequiel Palacios
# 86     partido       175  Exequiel Palacios
# 8           en       173  Exequiel Palacios
# 151     nicolá       167  Exequiel Palacios
# 179   martínez       165  Exequiel Palacios
# 157      messi       143  Exequiel Palacios
# 117         lo       136  Exequiel Palacios
# 156     lionel       136  Exequiel Palacios
# 43      equipo       136  Exequiel Palacios
# 137      mundo       133  Exequiel Palacios
# 136       copa       132  Exequiel Palacios
# 203         de       131  Exequiel Palacios
# 88         año       131  Exequiel Palacios
# 140  argentina       131  Exequiel Palacios
# 159    jugador       129  Exequiel Palacios
# 62           y       114  Exequiel Palacios
# 32          do       108  Exequiel Palacios
# 97     estadio        97  Exequiel Palacios
#
# Top Words for  Jeremie Frimpong
#            Word Frequency            player
# 5           el       252  Jeremie Frimpong
# 64          no       127  Jeremie Frimpong
# 119       club        81  Jeremie Frimpong
# 84          en        77  Jeremie Frimpong
# 68          de        76  Jeremie Frimpong
# 11          la        73  Jeremie Frimpong
# 156          a        65  Jeremie Frimpong
# 65      equipo        64  Jeremie Frimpong
# 93         año        58  Jeremie Frimpong
# 7      partido        56  Jeremie Frimpong
# 126  temporada        55  Jeremie Frimpong
# 39          xa        48  Jeremie Frimpong
# 42         tra        46  Jeremie Frimpong
# 35     jugador        45  Jeremie Frimpong
# 23       final        42  Jeremie Frimpong
# 51     mercado        42  Jeremie Frimpong
# 76          do        42  Jeremie Frimpong
# 52      fichaj        40  Jeremie Frimpong
# 3       europa        37  Jeremie Frimpong
# 4        leagu        36  Jeremie Frimpong
#
# Top Words for  Mitchel Bakker
#           Word Frequency          player
# 4     partido        28  Mitchel Bakker
# 2          no        24  Mitchel Bakker
# 1      equipo        23  Mitchel Bakker
# 10     minuto        19  Mitchel Bakker
# 3          en        17  Mitchel Bakker
# 17        gol        16  Mitchel Bakker
# 13     alonso        15  Mitchel Bakker
# 12       xabi        14  Mitchel Bakker
# 5         ida        13  Mitchel Bakker
# 9    marcador        13  Mitchel Bakker
# 20         do        12  Mitchel Bakker
# 18      rival        11  Mitchel Bakker
# 19      final        11  Mitchel Bakker
# 23    segundo         9  Mitchel Bakker
# 21     tiempo         9  Mitchel Bakker
# 24     hlozek         8  Mitchel Bakker
# 26      union         8  Mitchel Bakker
# 11   dirigido         8  Mitchel Bakker
# 7   temporada         8  Mitchel Bakker
# 6     triunfo         7  Mitchel Bakker
#
# Top Words for  Moussa Diaby
#          Word Frequency        player
# 7         el       134  Moussa Diaby
# 121       no        89  Moussa Diaby
# 26   partido        86  Moussa Diaby
# 92    equipo        57  Moussa Diaby
# 10    minuto        56  Moussa Diaby
# 25        en        48  Moussa Diaby
# 56        la        48  Moussa Diaby
# 106   alonso        46  Moussa Diaby
# 5     europa        45  Moussa Diaby
# 3      final        42  Moussa Diaby
# 105     xabi        41  Moussa Diaby
# 6      leagu        37  Moussa Diaby
# 19       tra        36  Moussa Diaby
# 29      gole        36  Moussa Diaby
# 13       gol        34  Moussa Diaby
# 75   jugador        31  Moussa Diaby
# 15        do        30  Moussa Diaby
# 46         a        30  Moussa Diaby
# 186     club        29  Moussa Diaby
# 145  francia        25  Moussa Diaby
#
# Top Words for  Mykhaylo Mudryk
#            Word Frequency           player
# 25      millon       113  Mykhaylo Mudryk
# 29          el        89  Mykhaylo Mudryk
# 79     jugador        67  Mykhaylo Mudryk
# 11   temporada        62  Mykhaylo Mudryk
# 27      fichaj        60  Mykhaylo Mudryk
# 33        euro        56  Mykhaylo Mudryk
# 91        club        52  Mykhaylo Mudryk
# 5       equipo        52  Mykhaylo Mudryk
# 34         año        45  Mykhaylo Mudryk
# 73        enzo        43  Mykhaylo Mudryk
# 61          en        43  Mykhaylo Mudryk
# 6      mercado        42  Mykhaylo Mudryk
# 37     partido        37  Mykhaylo Mudryk
# 62      fútbol        36  Mykhaylo Mudryk
# 123         la        35  Mykhaylo Mudryk
# 74   fernández        35  Mykhaylo Mudryk
# 107     boehli        31  Mykhaylo Mudryk
# 20          lo        30  Mykhaylo Mudryk
# 1      premier        30  Mykhaylo Mudryk
# 170   champion        30  Mykhaylo Mudryk
#
# Top Words for  Piero Hincapié
#              Word Frequency          player
# 8             el       260  Piero Hincapié
# 40            no       135  Piero Hincapié
# 15            la       108  Piero Hincapié
# 76       ecuador       107  Piero Hincapié
# 24            en       107  Piero Hincapié
# 27       partido       103  Piero Hincapié
# 206       equipo        74  Piero Hincapié
# 6    ecuatoriano        73  Piero Hincapié
# 127           lo        70  Piero Hincapié
# 2        sánchez        67  Piero Hincapié
# 4        jugador        60  Piero Hincapié
# 249        final        54  Piero Hincapié
# 459        marzo        53  Piero Hincapié
# 3         europa        52  Piero Hincapié
# 67            de        51  Piero Hincapié
# 1          félix        51  Piero Hincapié
# 116       minuto        50  Piero Hincapié
# 121          gol        47  Piero Hincapié
# 152           do        47  Piero Hincapié
# 179      primera        47  Piero Hincapié
