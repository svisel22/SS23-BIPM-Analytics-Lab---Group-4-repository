# %% [markdown]
# Purpose of this Notebooks is to test the News-API (https://newsapi.org)

# %%
# !pip install newsapi-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pprint
import requests
from newsapi import NewsApiClient

# %% [markdown]
# # First select 100 Articles with Mitchel Bakker in Title
# Within the News-website there are 80 Mio Newspages also including Sportwebsites. Eventhough there are zero articles with Mitchel Bakker in the Title

# %%
secret = '629525a47ff6458789d19a3c489419fa'
  
# Define the endpoint
url = 'https://newsapi.org/v2/everything'
  
# Specify the query and number of returns
parameters_bakker = {
    'q': 'Mitchel Bakker', # query phrase
    'pageSize': 100,  # maximum is 100
    'apiKey': secret, # your own API key
    'sortBy':'publishedAt',
    'searchIn': 'title' 
    # 'language': 'en' 'de' 'nl' 'es'
}

#GET https://newsapi.org/v2/everything?q=Apple&from=2023-04-18&&apiKey=API_KEY

  
# Make the request
response = requests.get(url,
                        params = parameters_bakker)
  
# Convert the response to
# JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [], 'status': 'ok', 'totalResults': 0}

# %% [markdown]
# # Searching for Messi/Wirtz to test out headlines
# Default the API throws out data within the last month.
# Next try was to test out more popular players to see if there is enough data existing. For Florian Wirtz (searched just for Wirtz) 96 Articles with Headlines appeared (532 with checking not just Headlines). Messi reached 2091 (6594 not just looking at Headlines).

# %%
# Specify the query and number of returns
parameters_wirtz = {
    'q': 'Wirtz', # query phrase
    'pageSize': 100,  # maximum is 100
    'apiKey': secret, # your own API key
    'sortBy':'publishedAt',
    'searchIn': 'title' 
}

response = requests.get(url,
                        params = parameters_wirtz)

# Convert the response to
# JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'STERN.de',
#                'content': 'Vor rund einem halben Jahr wurde Gerardo Seoane bei '
#                           'Bayer Leverkusen beurlaubt. Der Trainer hat seinen '
#                           'Frieden damit geschlossen. Und traut Ex-Spieler '
#                           'Florian Wirtz und Nachfolger Xabi Alonso viel zu… '
#                           '[+1963 chars]',
#                'description': 'Vor rund einem halben Jahr wurde Gerardo Seoane '
#                               'bei Bayer Leverkusen beurlaubt. Der Trainer hat '
#                               'seinen Frieden damit geschlossen. Und traut '
#                               'Ex-Spieler Florian Wirtz und Nachfolger Xabi '
#                               'Alonso viel zu.',
#                'publishedAt': '2023-04-19T10:27:04Z',
#                'source': {'id': None, 'name': 'STERN.de'},
#                'title': 'Bundesliga: Ex-Leverkusen Coach Seoane traut Wirtz '
# ...

# %%
# Specify the query and number of returns
parameters_messi = {
    'q': 'Messi', # query phrase
    'pageSize': 100,  # maximum is 100
    'apiKey': secret, # your own API key
    'sortBy':'publishedAt',
    #'searchIn': 'title' 
}

response = requests.get(url,
                        params = parameters_messi)

# Convert the response to
# JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'SVL',
#                'content': 'Vorige week werd Kevin De Bruyne, tegen zijn zin, '
#                           'na een uur gewisseld in de heenmatch tegen Bayern '
#                           'München. Voor de Champions League-return in München '
#                           'kwamen Marc Degryse en Jan Mulder in de studio … '
#                           '[+157 chars]',
#                'description': 'Vorige week werd Kevin De Bruyne, tegen zijn '
#                               'zin, na een uur gewisseld in de heenmatch tegen '
#                               'Bayern München. Voor de Champions League-return '
#                               'in München kwamen Marc Degryse en Jan Mulder in '
#                               'de studio terug op het akkefietje. “Dit heeft '
#                               'Guardiola nooit gedaan m…',
#                'publishedAt': '2023-04-19T19:31:55Z',
#                'source': {'id': None, 'name': 'Www.hln.be'},
# ...

# %% [markdown]
# # Check for all players with not just Headlines withing a Year
# Approach could then be to screen the Articles for Sentences where the Name pops up and just use these parts of the text.
#
# **Article Counts**
#
# Mitchel Bakker: 583
#
# Jeremie Frimpong: 1431
#
# Moussa Diaby: 1703
#
# Jonathan Tah: 454
#
# Piero Hincapie: 515
#
# Exequiel Palacios: 1005
#
# Mykhaylo Mudryk: 1540
#
# Lionel Messi: 59824

# %%
# Specify the query and number of returns for Mitchel Bakker
parameters_bakker = {
    'q': 'Mitchel Bakker', # query phrase
    'pageSize': 100,  # maximum is 100
    'apiKey': secret, # your own API key
    'sortBy':'publishedAt', # sorting by date
    'from': '2023-04-18', # form
    'to': '2022-04-18' # to
}

# Specify the query and number of returns for Jeremie Frimpong
parameters_frimpong = {
    'q': 'Mitchel Bakker', # query phrase
    'pageSize': 100,  # maximum is 100
    'apiKey': secret, # your own API key
    'sortBy':'publishedAt',
    'from': '2023-04-18',
    'to': '2022-04-18',
    'searchIn': 'title' 

}


# Specify the query and number of returns for Moussa Diaby
parameters_diaby = {
    'q': 'Moussa Diaby', # query phrase
    'pageSize': 100,  # maximum is 100
    'apiKey': secret, # your own API key
    'sortBy':'publishedAt',
    'from': '2023-04-18',
    'to': '2022-04-18'
}

# Specify the query and number of returns for Jonathan Tah
parameters_tah = {
    'q': 'Jonathan Tah', # query phrase
    'pageSize': 100,  # maximum is 100
    'apiKey': secret, # your own API key
    'sortBy':'publishedAt',
    'from': '2023-04-18',
    'to': '2022-04-18'
}

# Specify the query and number of returns for Piero Hincapie
parameters_hincapie = {
    'q': 'Piero Hincapie', # query phrase
    'pageSize': 100,  # maximum is 100
    'apiKey': secret, # your own API key
    'sortBy':'publishedAt',
    'from': '2023-04-18',
    'to': '2022-04-18'
}

# Specify the query and number of returns for Exequiel Palacios
parameters_palacios = {
    'q': 'Exequiel Palacios', # query phrase
    'pageSize': 100,  # maximum is 100
    'apiKey': secret, # your own API key
    'sortBy':'publishedAt',
    'from': '2023-04-18',
    'to': '2022-04-18'
}


# Specify the query and number of returns for Mykhaylo Mudryk
parameters_mudryk = {
    'q': 'Mykhaylo Mudryk', # query phrase
    'pageSize': 100,  # maximum is 100
    'apiKey': secret, # your own API key
    'sortBy':'publishedAt',
    'from': '2023-04-18',
    'to': '2022-04-18'
}


# Specify the query and number of returns for Lionel Messi
parameters_messi = {
    'q': 'Lionel Messi', # query phrase
    'pageSize': 100,  # maximum is 100
    'apiKey': secret, # your own API key
    'sortBy':'publishedAt', # sorting by date
    'from': '2023-04-18', # from
    'to': '2022-04-18' # to
}


response = requests.get(url,
                        params = parameters_frimpong)

# Convert the response to
# JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)

# %% [markdown]
# # Page size + Preprocessing
