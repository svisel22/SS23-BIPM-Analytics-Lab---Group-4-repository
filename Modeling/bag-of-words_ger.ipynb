# %% [markdown]
# # Stematization

# %%
from gensim.parsing.preprocessing import stem_text
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.corpora import Dictionary
from gensim.models import TfidfModel
sys.path.append('../')
from utils import word_frequency_per_player

# %% [markdown]
# ## Display the Frequency of words for each player

# %%
df_de = pd.read_csv('/Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/Preprocessing/data_clean/de_clean_condensed.csv')
df_en = pd.read_csv('/Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/Preprocessing/data_clean/en_clean_condensed.csv')
df_es = pd.read_csv('/Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/Preprocessing/data_clean/es_clean_condensed.csv')

df_freq_de = word_frequency_per_player(df_de, df_de['player'].unique())
df_freq_en = word_frequency_per_player(df_en, df_en['player'].unique())
df_freq_es = word_frequency_per_player(df_es, df_es['player'].unique())

# %%
# Subset for rows in Categoric
def print_player_freq(df_freq):
    df_freq_res = pd.DataFrame()
    
    for player in df_freq['player'].unique():
        # Delete rows we don't want to see
        # Define the strings to be deleted
        strings_to_delete = ['palacio', 'bayerleverkusen','andrich','leverkusen', 'bayer', 'au', 'fur', 'nicht', 'diabi','alonso', 'wurd', 'hatt', 'zwei', 'seit', 'acht',
                             'man', 'get', 'player','july', 's', 't', 'it',
                             'ma', 'do', 'tambien', 'tra', 'xa']

        # Delete rows containing the specified strings 
        df_freq = df_freq[~df_freq['Word'].isin(strings_to_delete)]


        df_player = df_freq[(df_freq["player"] == player)]
        print('Top Words for ', player , '\n', df_player.head(20), '\n')

        df_freq_res  = pd.concat([df_freq_res, df_player.head(20)], axis=0)

    
    return df_freq_res

#'exequiel', 'frimpong', 'jeremi', 'tah', 'jonathan', 'bakker', 'mitchel', 'moussa', 'diaby', 'mykhaylo', 'piero', 'hincapie',

# %%
# print frequencies per player for german data
df_freq_de = print_player_freq(df_freq_de)
# Out:
# Top Words for  exequiel palacios
#              Word  Frequency             player
# 40     weltmeist         48  exequiel palacios
# 16         spiel         46  exequiel palacios
# 80          adli         39  exequiel palacios
# 64          sagt         29  exequiel palacios
# 48         saint         27  exequiel palacios
# 18      hinspiel         27  exequiel palacios
# 135        wirtz         27  exequiel palacios
# 59    bundesliga         27  exequiel palacios
# 1        trainer         26  exequiel palacios
# 78        elfmet         26  exequiel palacios
# 45         union         25  exequiel palacios
# 71        bayern         22  exequiel palacios
# 92       stieler         21  exequiel palacios
# 49       gillois         21  exequiel palacios
# 17    donnerstag         21  exequiel palacios
# 132      tapsoba         21  exequiel palacios
# 12         amiri         20  exequiel palacios
# 21          gelb         20  exequiel palacios
# ...

# %%
# print frequencies per player for english data
df_freq_en = print_player_freq(df_freq_en)
# Out:
# Top Words for  exequiel palacios
#             Word Frequency             player
# 96         goal       106  exequiel palacios
# 4           win        91  exequiel palacios
# 92       bayern        91  exequiel palacios
# 7          game        76  exequiel palacios
# 20        minut        66  exequiel palacios
# 36        score        55  exequiel palacios
# 210       point        54  exequiel palacios
# 8          time        52  exequiel palacios
# 5        second        50  exequiel palacios
# 104        half        48  exequiel palacios
# 100    dortmund        38  exequiel palacios
# 95       season        38  exequiel palacios
# 26         lead        36  exequiel palacios
# 94   bundesliga        35  exequiel palacios
# 3       penalti        35  exequiel palacios
# 116        shot        34  exequiel palacios
# 9          team        34  exequiel palacios
# 120         top        33  exequiel palacios
# 50         real        33  exequiel palacios
# ...

# %%
# print frequencies per player for spanish data
df_freq_es = print_player_freq(df_freq_es)
# Out:
# Top Words for  exequiel palacios
#            Word Frequency             player
# 172   martinez       127  exequiel palacios
# 190     nicola       108  exequiel palacios
# 183      angel        88  exequiel palacios
# 67      lionel        71  exequiel palacios
# 96     campeon        71  exequiel palacios
# 97       mundo        67  exequiel palacios
# 184     correa        66  exequiel palacios
# 18       marco        59  exequiel palacios
# 69     leandro        53  exequiel palacios
# 79       messi        53  exequiel palacios
# 113    montiel        52  exequiel palacios
# 275   emiliano        52  exequiel palacios
# 196     dybala        51  exequiel palacios
# 62   fernandez        50  exequiel palacios
# 195      paulo        50  exequiel palacios
# 289    lautaro        50  exequiel palacios
# 112    gonzalo        49  exequiel palacios
# 70       pared        49  exequiel palacios
# 193      maria        49  exequiel palacios
# ...

# %%
df_freq_de['language'] = 'de'
df_freq_en['language'] = 'en'
df_freq_es['language'] = 'es'

# %%
df_freq_all  = pd.concat([df_freq_de, df_freq_en, df_freq_es], axis=0)

# %%
df_freq_all.to_csv('/Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/TWSM/TWSM Project/SS23-BIPM-Analytics-Lab---Group-4-repository/Modeling/modeled_data/word_frequencies.csv')
